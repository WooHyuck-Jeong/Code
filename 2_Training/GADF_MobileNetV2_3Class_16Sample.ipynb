# %%
import os
import glob
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import keras
import tensorflow as tf
from keras import optimizers
from keras.utils import to_categorical
from keras.layers import Dense, Input
from keras.models import Model, load_model
from keras.applications import MobileNetV2
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
dataPath = "../1_Data_Preprocessing/16Sample/3Class/GADF_3Class_16Sample.npz"
data = np.load(dataPath)

X_data = data['X_data']
y_data = data['y_data']
i_data = data['i_data']

data.close()

print("X_data: ", X_data.shape)
print("y_data: ", y_data.shape)
print("i_data: ", i_data.shape)
# Out:
# X_data:  (2160, 16, 16, 3)
# y_data:  (2160,)
# i_data:  (2160,)

# %%
# Data split

# Set random seed for reproductivity
seed = 42

# Train - Test split
X_train, X_test, y_train, y_test, i_train, i_test = train_test_split(X_data, y_data, i_data, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_data)

# Train - Validation split
X_train, X_val, y_train, y_val, i_train, i_val = train_test_split(X_train, y_train, i_train, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_train)

print(X_train.shape, X_test.shape, X_val.shape)
print(y_train.shape, y_test.shape, y_val.shape)
print(i_train.shape, i_test.shape, i_val.shape)

print(np.unique(y_train, return_counts= True))
print(np.unique(y_test, return_counts= True))
print(np.unique(y_val, return_counts= True))
# Out:
# (1382, 16, 16, 3) (432, 16, 16, 3) (346, 16, 16, 3)
# (1382,) (432,) (346,)
# (1382,) (432,) (346,)
# (array([0, 1, 2], dtype=int64), array([461, 461, 460], dtype=int64))
# (array([0, 1, 2], dtype=int64), array([144, 144, 144], dtype=int64))
# (array([0, 1, 2], dtype=int64), array([115, 115, 116], dtype=int64))

# %%
# One - hot encoding
trainTargets = to_categorical(y_train)
testTargets = to_categorical(y_test)
valTargets = to_categorical(y_val)

print("Train targets: ", trainTargets.shape)
print("Test targets: ", testTargets.shape)
print("Validation targets: ", valTargets.shape)
# Out:
# Train targets:  (1382, 3)
# Test targets:  (432, 3)
# Validation targets:  (346, 3)

# %%
weightPath = "./weights/"

# %%
# MobileNetV2 Transfer-learning
# Import convolution layer
# weight = None

with tf.device("/device:GPU:0"):
    inputTensor = Input(shape= (16, 16, 3))

    model = MobileNetV2(input_tensor= inputTensor,              # Input data shape
                        include_top= False,                     # Only convolution layer. If True: Use Classification layer
                        weights= None,                          # If weights= "imagenet" --> Use imagenet weights
                        pooling= 'max')

    x = model.output
    x = Dense(3, activation= 'softmax', kernel_initializer= 'he_normal')(x)

    model = Model(model.input, x)

    # Instantiate optimizer
    optim = optimizers.SGD(learning_rate= 0.01,
                           decay= 1e-3,
                           momentum= 0.9,
                           nesterov= True)

    # Compile model
    model.compile(optimizer= optim,
                  loss= 'categorical_crossentropy',
                  metrics= ['accuracy'])

    print("Training======================================")
    startTime = time.time()                                     # Training start time

    history = model.fit(X_train, trainTargets,
                        batch_size= 16,
                        epochs= 200,
                        verbose= 1,
                        validation_data= (X_val, valTargets)
                        )
    
    endTime = time.time()                                       # Training end time
    print(f"Training time: {np.round(endTime - startTime, 3)} sec")

    # save weight file
    model.save(os.path.join(weightPath, "GADF_MobileNetV2_3Class_16Sample.h5"))

    # Evaluate for total train dataset
    print("Score for train dataset")
    score = model.evaluate(X_train, trainTargets, verbose= 1)
    print(f"Score: \n{model.metrics_names[0]} : {score[0]}\n{model.metrics_names[0]} : {score[1] * 100} %")
# Out:
# Training======================================
# Epoch 1/200
# 87/87 [==============================] - 9s 41ms/step - loss: 0.9759 - accuracy: 0.6860 - val_loss: 1.1057 - val_accuracy: 0.3324
# Epoch 2/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.3176 - accuracy: 0.9103 - val_loss: 1.1118 - val_accuracy: 0.3324
# Epoch 3/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.2894 - accuracy: 0.9139 - val_loss: 1.1082 - val_accuracy: 0.3324
# Epoch 4/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.1651 - accuracy: 0.9457 - val_loss: 1.1104 - val_accuracy: 0.3324
# Epoch 5/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.1158 - accuracy: 0.9595 - val_loss: 1.1090 - val_accuracy: 0.3324
# Epoch 6/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.1764 - accuracy: 0.9667 - val_loss: 1.1166 - val_accuracy: 0.3324
# Epoch 7/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.1046 - accuracy: 0.9696 - val_loss: 1.1089 - val_accuracy: 0.3324
# Epoch 8/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0393 - accuracy: 0.9891 - val_loss: 1.1202 - val_accuracy: 0.3324
# Epoch 9/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0463 - accuracy: 0.9935 - val_loss: 1.1209 - val_accuracy: 0.3324
# Epoch 10/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0383 - accuracy: 0.9935 - val_loss: 1.1048 - val_accuracy: 0.3324
# Epoch 11/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0221 - accuracy: 0.9957 - val_loss: 1.1111 - val_accuracy: 0.3324
# Epoch 12/200
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0373 - accuracy: 0.9928 - val_loss: 1.1039 - val_accuracy: 0.3324
# Epoch 13/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0109 - accuracy: 0.9986 - val_loss: 1.1067 - val_accuracy: 0.3324
# Epoch 14/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0080 - accuracy: 0.9957 - val_loss: 1.1184 - val_accuracy: 0.3324
# Epoch 15/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 1.1347 - val_accuracy: 0.3324
# Epoch 16/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0414 - accuracy: 0.9942 - val_loss: 1.1462 - val_accuracy: 0.3324
# Epoch 17/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0421 - accuracy: 0.9942 - val_loss: 1.1197 - val_accuracy: 0.3324
# Epoch 18/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.1153 - val_accuracy: 0.3324
# Epoch 19/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0261 - accuracy: 0.9957 - val_loss: 1.1122 - val_accuracy: 0.3324
# Epoch 20/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0433 - accuracy: 0.9971 - val_loss: 1.1076 - val_accuracy: 0.3324
# Epoch 21/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0305 - accuracy: 0.9928 - val_loss: 1.0763 - val_accuracy: 0.3324
# Epoch 22/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0059 - accuracy: 0.9986 - val_loss: 1.1201 - val_accuracy: 0.3324
# Epoch 23/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0444 - accuracy: 0.9942 - val_loss: 1.0937 - val_accuracy: 0.3324
# Epoch 24/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0601 - accuracy: 0.9812 - val_loss: 1.1042 - val_accuracy: 0.3324
# Epoch 25/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0156 - accuracy: 0.9978 - val_loss: 1.0762 - val_accuracy: 0.3324
# Epoch 26/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0519 - accuracy: 0.9928 - val_loss: 1.1053 - val_accuracy: 0.3324
# Epoch 27/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0357 - accuracy: 0.9971 - val_loss: 1.0851 - val_accuracy: 0.3324
# Epoch 28/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.0652 - val_accuracy: 0.3324
# Epoch 29/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0246 - accuracy: 0.9942 - val_loss: 1.0509 - val_accuracy: 0.3324
# Epoch 30/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0198 - accuracy: 0.9957 - val_loss: 1.0294 - val_accuracy: 0.3324
# Epoch 31/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0237 - accuracy: 0.9957 - val_loss: 1.0383 - val_accuracy: 0.3324
# Epoch 32/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0126 - accuracy: 0.9971 - val_loss: 1.1098 - val_accuracy: 0.3324
# Epoch 33/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0440 - accuracy: 0.9949 - val_loss: 1.0932 - val_accuracy: 0.3324
# Epoch 34/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0222 - accuracy: 0.9949 - val_loss: 1.0160 - val_accuracy: 0.4971
# Epoch 35/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0202 - accuracy: 0.9964 - val_loss: 0.9748 - val_accuracy: 0.3642
# Epoch 36/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0436 - accuracy: 0.9942 - val_loss: 0.8991 - val_accuracy: 0.4538
# Epoch 37/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0514 - accuracy: 0.9899 - val_loss: 0.9448 - val_accuracy: 0.3324
# Epoch 38/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0073 - accuracy: 0.9993 - val_loss: 0.9105 - val_accuracy: 0.3324
# Epoch 39/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0332 - accuracy: 0.9957 - val_loss: 0.8647 - val_accuracy: 0.5896
# Epoch 40/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.8421 - val_accuracy: 0.4393
# Epoch 41/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0343 - accuracy: 0.9942 - val_loss: 0.8178 - val_accuracy: 0.7052
# Epoch 42/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0168 - accuracy: 0.9978 - val_loss: 0.8150 - val_accuracy: 0.5838
# Epoch 43/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.7730 - val_accuracy: 0.6705
# Epoch 44/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0095 - accuracy: 0.9993 - val_loss: 0.7235 - val_accuracy: 0.7486
# Epoch 45/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.6647 - val_accuracy: 0.8497
# Epoch 46/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0315 - accuracy: 0.9935 - val_loss: 0.6604 - val_accuracy: 0.8064
# Epoch 47/200
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0206 - accuracy: 0.9978 - val_loss: 0.6088 - val_accuracy: 0.9855
# Epoch 48/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0361 - accuracy: 0.9920 - val_loss: 0.5615 - val_accuracy: 1.0000
# Epoch 49/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0111 - accuracy: 0.9993 - val_loss: 0.5043 - val_accuracy: 1.0000
# Epoch 50/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0257 - accuracy: 0.9971 - val_loss: 0.4818 - val_accuracy: 1.0000
# Epoch 51/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0141 - accuracy: 0.9971 - val_loss: 0.4752 - val_accuracy: 0.9624
# Epoch 52/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0201 - accuracy: 0.9964 - val_loss: 0.4375 - val_accuracy: 0.9942
# Epoch 53/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.3877 - val_accuracy: 1.0000
# Epoch 54/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0072 - accuracy: 0.9964 - val_loss: 0.3411 - val_accuracy: 1.0000
# Epoch 55/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0078 - accuracy: 0.9993 - val_loss: 0.3504 - val_accuracy: 0.9306
# Epoch 56/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0160 - accuracy: 0.9957 - val_loss: 0.4418 - val_accuracy: 0.7341
# Epoch 57/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0308 - accuracy: 0.9906 - val_loss: 0.4719 - val_accuracy: 0.8642
# Epoch 58/200
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3895 - val_accuracy: 0.9509
# Epoch 59/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0111 - accuracy: 0.9993 - val_loss: 0.3206 - val_accuracy: 0.9769
# Epoch 60/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9971
# Epoch 61/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0128 - accuracy: 0.9978 - val_loss: 0.2215 - val_accuracy: 1.0000
# Epoch 62/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0149 - accuracy: 0.9978 - val_loss: 0.2162 - val_accuracy: 1.0000
# Epoch 63/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.1825 - val_accuracy: 1.0000
# Epoch 64/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 1.0000
# Epoch 65/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 1.0000
# Epoch 66/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0267 - accuracy: 0.9957 - val_loss: 0.1721 - val_accuracy: 1.0000
# Epoch 67/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0503 - accuracy: 0.9899 - val_loss: 0.2025 - val_accuracy: 1.0000
# Epoch 68/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0299 - accuracy: 0.9978 - val_loss: 0.1599 - val_accuracy: 1.0000
# Epoch 69/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0285 - accuracy: 0.9935 - val_loss: 0.2017 - val_accuracy: 0.9942
# Epoch 70/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 1.0000
# Epoch 71/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0915 - val_accuracy: 1.0000
# Epoch 72/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0165 - accuracy: 0.9978 - val_loss: 0.0879 - val_accuracy: 1.0000
# Epoch 73/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0116 - accuracy: 0.9978 - val_loss: 0.0709 - val_accuracy: 1.0000
# Epoch 74/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0068 - accuracy: 0.9986 - val_loss: 0.0617 - val_accuracy: 1.0000
# Epoch 75/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0520 - val_accuracy: 1.0000
# Epoch 76/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0042 - accuracy: 0.9993 - val_loss: 0.0446 - val_accuracy: 1.0000
# Epoch 77/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 1.0000
# Epoch 78/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0100 - accuracy: 0.9978 - val_loss: 0.0498 - val_accuracy: 1.0000
# Epoch 79/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0097 - accuracy: 0.9993 - val_loss: 0.0399 - val_accuracy: 1.0000
# Epoch 80/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 1.0000
# Epoch 81/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.0619 - val_accuracy: 1.0000
# Epoch 82/200
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0488 - val_accuracy: 1.0000
# Epoch 83/200
# 87/87 [==============================] - 2s 20ms/step - loss: 8.0097e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 84/200
# 87/87 [==============================] - 2s 21ms/step - loss: 8.2614e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 1.0000
# Epoch 85/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0104 - accuracy: 0.9978 - val_loss: 0.0387 - val_accuracy: 1.0000
# Epoch 86/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0100 - accuracy: 0.9986 - val_loss: 0.0424 - val_accuracy: 1.0000
# Epoch 87/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0250 - accuracy: 0.9964 - val_loss: 0.0723 - val_accuracy: 1.0000
# Epoch 88/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0042 - accuracy: 0.9993 - val_loss: 0.0564 - val_accuracy: 1.0000
# Epoch 89/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 90/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 0.0355 - val_accuracy: 1.0000
# Epoch 91/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0096 - accuracy: 0.9978 - val_loss: 0.0520 - val_accuracy: 1.0000
# Epoch 92/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0050 - accuracy: 0.9993 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 93/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0197 - accuracy: 0.9986 - val_loss: 0.0398 - val_accuracy: 1.0000
# Epoch 94/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 1.0000
# Epoch 95/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 96/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 97/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0175 - accuracy: 0.9978 - val_loss: 0.0762 - val_accuracy: 0.9653
# Epoch 98/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0058 - accuracy: 0.9993 - val_loss: 0.0425 - val_accuracy: 0.9971
# Epoch 99/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 1.0000
# Epoch 100/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 101/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 102/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0079 - accuracy: 0.9986 - val_loss: 0.0228 - val_accuracy: 1.0000
# Epoch 103/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0048 - accuracy: 0.9993 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 104/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.0220 - val_accuracy: 1.0000
# Epoch 105/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 0.0275 - val_accuracy: 1.0000
# Epoch 106/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 107/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0053 - accuracy: 0.9993 - val_loss: 0.0233 - val_accuracy: 1.0000
# Epoch 108/200
# 87/87 [==============================] - 2s 22ms/step - loss: 6.4560e-04 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 109/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 110/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 111/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0345 - accuracy: 0.9928 - val_loss: 0.0179 - val_accuracy: 1.0000
# Epoch 112/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 113/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0200 - accuracy: 0.9957 - val_loss: 0.0266 - val_accuracy: 1.0000
# Epoch 114/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 1.0000
# Epoch 115/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0087 - accuracy: 0.9993 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 116/200
# 87/87 [==============================] - 2s 21ms/step - loss: 8.0419e-04 - accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 117/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0127 - accuracy: 0.9986 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 118/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 119/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 120/200
# 87/87 [==============================] - 2s 22ms/step - loss: 8.0723e-04 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 121/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0517 - accuracy: 0.9891 - val_loss: 0.0292 - val_accuracy: 1.0000
# Epoch 122/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0052 - accuracy: 0.9993 - val_loss: 0.0187 - val_accuracy: 1.0000
# Epoch 123/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 124/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0272 - accuracy: 0.9964 - val_loss: 0.0461 - val_accuracy: 1.0000
# Epoch 125/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0210 - accuracy: 0.9949 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 126/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 1.0000
# Epoch 127/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0291 - accuracy: 0.9957 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 128/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 129/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0048 - accuracy: 0.9993 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 130/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 1.0000
# Epoch 131/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0157 - accuracy: 0.9957 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 132/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 133/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 134/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0119 - accuracy: 0.9986 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 135/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 136/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 137/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0206 - accuracy: 0.9949 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 138/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 139/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 140/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 141/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 142/200
# 87/87 [==============================] - 2s 20ms/step - loss: 6.5570e-04 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 143/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 144/200
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 145/200
# 87/87 [==============================] - 2s 21ms/step - loss: 8.1217e-04 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 146/200
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0159 - accuracy: 0.9949 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 147/200
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0124 - accuracy: 0.9986 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 148/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 149/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 150/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0210 - accuracy: 0.9906 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 151/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0071 - accuracy: 0.9986 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 152/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 153/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 154/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0162 - accuracy: 0.9942 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 155/200
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0083 - accuracy: 0.9986 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 156/200
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0075 - accuracy: 0.9986 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 157/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 158/200
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 159/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 160/200
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 161/200
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0142 - accuracy: 0.9971 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 162/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 163/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0064 - accuracy: 0.9986 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 164/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0179 - accuracy: 0.9964 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 165/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 166/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0109 - accuracy: 0.9986 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 167/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0111 - accuracy: 0.9986 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 168/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0127 - accuracy: 0.9964 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 169/200
# 87/87 [==============================] - 2s 22ms/step - loss: 9.3559e-04 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 170/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 171/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 172/200
# 87/87 [==============================] - 2s 22ms/step - loss: 7.2734e-04 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 173/200
# 87/87 [==============================] - 2s 22ms/step - loss: 6.8240e-04 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 174/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0075 - accuracy: 0.9993 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 175/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 176/200
# 87/87 [==============================] - 2s 22ms/step - loss: 9.3505e-04 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 177/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 178/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0206 - accuracy: 0.9949 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 179/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0224 - val_accuracy: 1.0000
# Epoch 180/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0051 - accuracy: 0.9993 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 181/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0072 - accuracy: 0.9971 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 182/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0193 - accuracy: 0.9978 - val_loss: 0.0256 - val_accuracy: 1.0000
# Epoch 183/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 0.0575 - val_accuracy: 0.9971
# Epoch 184/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0471 - val_accuracy: 1.0000
# Epoch 185/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0394 - val_accuracy: 1.0000
# Epoch 186/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 1.0000
# Epoch 187/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 188/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0059 - accuracy: 0.9971 - val_loss: 0.0303 - val_accuracy: 1.0000
# Epoch 189/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0064 - accuracy: 0.9986 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 190/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 191/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 192/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.0478 - val_accuracy: 0.9971
# Epoch 193/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.0355 - val_accuracy: 1.0000
# Epoch 194/200
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0180 - accuracy: 0.9971 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 195/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.0433 - val_accuracy: 1.0000
# Epoch 196/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0290 - val_accuracy: 1.0000
# Epoch 197/200
# 87/87 [==============================] - 2s 22ms/step - loss: 8.7288e-04 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 1.0000
# Epoch 198/200
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 199/200
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 200/200
# 87/87 [==============================] - 2s 22ms/step - loss: 8.9952e-04 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 1.0000
# Training time: 388.654 sec
# Score for train dataset
# 44/44 [==============================] - 1s 8ms/step - loss: 0.0172 - accuracy: 1.0000
# Score:
# loss : 0.017189037054777145
# loss : 100.0 %

# %%
def plotHistory(history, train, validation):
    """
        plot training history
        Parameters
        ------------------------------
        history = history
        train = 'accuracy' or 'loss'
        validation = 'val_accuracy' or 'val_loss'
    """
    plt.figure(figsize= (8, 6))
    plt.plot(history.history[train])
    plt.plot(history.history[validation])
    plt.legend(['train', 'validation'], loc= 'center right')
    plt.xlabel("Epochs")
    if train == 'accuracy':
        plt.ylabel("Accuracy")
        plt.title(f"Accuracy for train dataset")
    elif train == "loss":
        plt.ylabel("Loss")
        plt.title("Loss for train dataset")
    plt.show()

# %%
plotHistory(history= history, train= 'accuracy', validation= 'val_accuracy')
plotHistory(history= history, train= 'loss', validation= 'val_loss')

# %%
# Prediction for test dataset

prediction = model.predict(X_test)
predictionClass = np.argmax(prediction, axis= 1)        # One-hot encoding --> Original label

# Actual Class (One-hot encoding testTarget --> y_test)
if testTargets.ndim > 1:
    actualClass = np.argmax(testTargets, axis= 1)
else:
    actualClass = testTargets

# Classification report
print(f"Classification report: \n{classification_report(actualClass, predictionClass)}")

# Confusion matrix
plt.figure(figsize= (8, 6))
sns.heatmap(confusion_matrix(actualClass, predictionClass), 
            annot= True, 
            fmt= "d", 
            cmap= "Blues",
            cbar= False)
plt.title("Confusion matrix for test dataset")
plt.xlabel("Prediction class")
plt.ylabel("Actual class")
plt.show()
# Out:
# 14/14 [==============================] - 1s 6ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       144
#            1       1.00      1.00      1.00       144
#            2       1.00      1.00      1.00       144
#
#     accuracy                           1.00       432
#    macro avg       1.00      1.00      1.00       432
# weighted avg       1.00      1.00      1.00       432

# %%
# Prediction for 1 image

randomImgIdx = random.randrange(0, X_test.shape[0])

predictStartTime = time.time()

predictionImg = X_test[randomImgIdx]
predictionImg = np.expand_dims(predictionImg, axis= 0)

testPrediction = model.predict(predictionImg)

predictEndTime = time.time()

print("Random image index: ", randomImgIdx)
print("Random actual label: ", i_test[randomImgIdx])
print("Random actual class: ", actualClass[randomImgIdx])
print("Random prediction class: ", predictionClass[randomImgIdx])
# Out:
# 1/1 [==============================] - 0s 238ms/step
# Random image index:  122
# Random actual label:  L_567
# Random actual class:  1
# Random prediction class:  1
