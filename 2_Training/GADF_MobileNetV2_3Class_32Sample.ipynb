# %%
import os
import glob
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import keras
import tensorflow as tf
from keras import optimizers
from keras.utils import to_categorical
from keras.layers import Dense, Input
from keras.models import Model, load_model
from keras.applications import MobileNetV2
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
dataPath = "../1_Data_Preprocessing/32Sample/3Class/GADF_3Class_32Sample.npz"
data = np.load(dataPath)

X_data = data['X_data']
y_data = data['y_data']
i_data = data['i_data']

data.close()

print("X_data: ", X_data.shape)
print("y_data: ", y_data.shape)
print("i_data: ", i_data.shape)
# Out:
# X_data:  (1080, 32, 32, 3)
# y_data:  (1080,)
# i_data:  (1080,)

# %%
# Data split

# Set random seed for reproductivity
seed = 42

# Train - Test split
X_train, X_test, y_train, y_test, i_train, i_test = train_test_split(X_data, y_data, i_data, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_data)

# Train - Validation split
X_train, X_val, y_train, y_val, i_train, i_val = train_test_split(X_train, y_train, i_train, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_train)

print(X_train.shape, X_test.shape, X_val.shape)
print(y_train.shape, y_test.shape, y_val.shape)
print(i_train.shape, i_test.shape, i_val.shape)

print(np.unique(y_train, return_counts= True))
print(np.unique(y_test, return_counts= True))
print(np.unique(y_val, return_counts= True))
# Out:
# (691, 32, 32, 3) (216, 32, 32, 3) (173, 32, 32, 3)
# (691,) (216,) (173,)
# (691,) (216,) (173,)
# (array([0, 1, 2], dtype=int64), array([231, 230, 230], dtype=int64))
# (array([0, 1, 2], dtype=int64), array([72, 72, 72], dtype=int64))
# (array([0, 1, 2], dtype=int64), array([57, 58, 58], dtype=int64))

# %%
# One - hot encoding
trainTargets = to_categorical(y_train)
testTargets = to_categorical(y_test)
valTargets = to_categorical(y_val)

print("Train targets: ", trainTargets.shape)
print("Test targets: ", testTargets.shape)
print("Validation targets: ", valTargets.shape)
# Out:
# Train targets:  (691, 3)
# Test targets:  (216, 3)
# Validation targets:  (173, 3)

# %%
weightPath = "./weights/"

# %%
# MobileNetV2 Transfer-learning
# Import convolution layer
# weight = None

with tf.device("/device:GPU:0"):
    inputTensor = Input(shape= (32, 32, 3))

    model = MobileNetV2(input_tensor= inputTensor,              # Input data shape
                        include_top= False,                     # Only convolution layer. If True: Use Classification layer
                        weights= None,                          # If weights= "imagenet" --> Use imagenet weights
                        pooling= 'max')

    x = model.output
    x = Dense(3, activation= 'softmax', kernel_initializer= 'he_normal')(x)

    model = Model(model.input, x)

    # Instantiate optimizer
    optim = optimizers.SGD(learning_rate= 0.01,
                           decay= 1e-3,
                           momentum= 0.9,
                           nesterov= True)

    # Compile model
    model.compile(optimizer= optim,
                  loss= 'categorical_crossentropy',
                  metrics= ['accuracy'])

    print("Training======================================")
    startTime = time.time()                                     # Training start time

    history = model.fit(X_train, trainTargets,
                        batch_size= 16,
                        epochs= 200,
                        verbose= 1,
                        validation_data= (X_val, valTargets)
                        )
    
    endTime = time.time()                                       # Training end time
    print(f"Training time: {np.round(endTime - startTime, 3)} sec")

    # save weight file
    model.save(os.path.join(weightPath, "GADF_MobileNetV2_3Class_32Sample.h5"))

    # Evaluate for total train dataset
    print("Score for train dataset")
    score = model.evaluate(X_train, trainTargets, verbose= 1)
    print(f"Score: \n{model.metrics_names[0]} : {score[0]}\n{model.metrics_names[0]} : {score[1] * 100} %")
# Out:
# Training======================================
# Epoch 1/200
# 44/44 [==============================] - 8s 60ms/step - loss: 0.8085 - accuracy: 0.7627 - val_loss: 1.1056 - val_accuracy: 0.3295
# Epoch 2/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.3026 - accuracy: 0.9190 - val_loss: 1.1425 - val_accuracy: 0.3295
# Epoch 3/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.1397 - accuracy: 0.9595 - val_loss: 1.1322 - val_accuracy: 0.3295
# Epoch 4/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0273 - accuracy: 0.9913 - val_loss: 1.1204 - val_accuracy: 0.3295
# Epoch 5/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0978 - accuracy: 0.9884 - val_loss: 1.1067 - val_accuracy: 0.3295
# Epoch 6/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0521 - accuracy: 0.9899 - val_loss: 1.1091 - val_accuracy: 0.3295
# Epoch 7/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0386 - accuracy: 0.9928 - val_loss: 1.1039 - val_accuracy: 0.3295
# Epoch 8/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0526 - accuracy: 0.9826 - val_loss: 1.1121 - val_accuracy: 0.3295
# Epoch 9/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0466 - accuracy: 0.9913 - val_loss: 1.1119 - val_accuracy: 0.3295
# Epoch 10/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0241 - accuracy: 0.9971 - val_loss: 1.1071 - val_accuracy: 0.3295
# Epoch 11/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0297 - accuracy: 0.9942 - val_loss: 1.1138 - val_accuracy: 0.3295
# Epoch 12/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0362 - accuracy: 0.9913 - val_loss: 1.1156 - val_accuracy: 0.3295
# Epoch 13/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.1013 - accuracy: 0.9768 - val_loss: 1.1207 - val_accuracy: 0.3295
# Epoch 14/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0963 - accuracy: 0.9768 - val_loss: 1.1154 - val_accuracy: 0.3295
# Epoch 15/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0180 - accuracy: 0.9957 - val_loss: 1.1283 - val_accuracy: 0.3295
# Epoch 16/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0552 - accuracy: 0.9928 - val_loss: 1.1315 - val_accuracy: 0.3295
# Epoch 17/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0491 - accuracy: 0.9913 - val_loss: 1.1163 - val_accuracy: 0.3295
# Epoch 18/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0425 - accuracy: 0.9928 - val_loss: 1.1166 - val_accuracy: 0.3295
# Epoch 19/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.1099 - accuracy: 0.9783 - val_loss: 1.1051 - val_accuracy: 0.3295
# Epoch 20/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0673 - accuracy: 0.9884 - val_loss: 1.1576 - val_accuracy: 0.3295
# Epoch 21/200
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0743 - accuracy: 0.9855 - val_loss: 1.2610 - val_accuracy: 0.3295
# Epoch 22/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.1425 - accuracy: 0.9855 - val_loss: 1.2143 - val_accuracy: 0.3295
# Epoch 23/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0830 - accuracy: 0.9812 - val_loss: 1.1671 - val_accuracy: 0.3295
# Epoch 24/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0351 - accuracy: 0.9913 - val_loss: 1.2117 - val_accuracy: 0.3295
# Epoch 25/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0668 - accuracy: 0.9913 - val_loss: 1.2729 - val_accuracy: 0.3295
# Epoch 26/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.3532 - accuracy: 0.8799 - val_loss: 1.2299 - val_accuracy: 0.3295
# Epoch 27/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0761 - accuracy: 0.9855 - val_loss: 1.2453 - val_accuracy: 0.3295
# Epoch 28/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.1606 - accuracy: 0.9624 - val_loss: 1.1601 - val_accuracy: 0.3295
# Epoch 29/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0614 - accuracy: 0.9783 - val_loss: 1.1946 - val_accuracy: 0.3295
# Epoch 30/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.1053 - accuracy: 0.9855 - val_loss: 1.2295 - val_accuracy: 0.3295
# Epoch 31/200
# 44/44 [==============================] - 1s 21ms/step - loss: 0.1919 - accuracy: 0.9378 - val_loss: 1.3093 - val_accuracy: 0.3295
# Epoch 32/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0763 - accuracy: 0.9783 - val_loss: 1.3057 - val_accuracy: 0.3295
# Epoch 33/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0299 - accuracy: 0.9942 - val_loss: 1.3157 - val_accuracy: 0.3295
# Epoch 34/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.1555 - accuracy: 0.9797 - val_loss: 1.2802 - val_accuracy: 0.3295
# Epoch 35/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0295 - accuracy: 0.9928 - val_loss: 1.2144 - val_accuracy: 0.3295
# Epoch 36/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0338 - accuracy: 0.9942 - val_loss: 1.2523 - val_accuracy: 0.3295
# Epoch 37/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0318 - accuracy: 0.9899 - val_loss: 1.2080 - val_accuracy: 0.3295
# Epoch 38/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0175 - accuracy: 0.9971 - val_loss: 1.3050 - val_accuracy: 0.3295
# Epoch 39/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0202 - accuracy: 0.9899 - val_loss: 1.3043 - val_accuracy: 0.3295
# Epoch 40/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.1350 - accuracy: 0.9826 - val_loss: 1.2181 - val_accuracy: 0.3295
# Epoch 41/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0459 - accuracy: 0.9928 - val_loss: 1.2207 - val_accuracy: 0.3295
# Epoch 42/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0487 - accuracy: 0.9928 - val_loss: 1.2409 - val_accuracy: 0.3295
# Epoch 43/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.1188 - accuracy: 0.9841 - val_loss: 1.3984 - val_accuracy: 0.3295
# Epoch 44/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0168 - accuracy: 0.9971 - val_loss: 1.3096 - val_accuracy: 0.3295
# Epoch 45/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0414 - accuracy: 0.9841 - val_loss: 1.4195 - val_accuracy: 0.3295
# Epoch 46/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0771 - accuracy: 0.9870 - val_loss: 1.2684 - val_accuracy: 0.3295
# Epoch 47/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0213 - accuracy: 0.9942 - val_loss: 1.1212 - val_accuracy: 0.3295
# Epoch 48/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0284 - accuracy: 0.9957 - val_loss: 1.1015 - val_accuracy: 0.3295
# Epoch 49/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0527 - accuracy: 0.9884 - val_loss: 1.0915 - val_accuracy: 0.3295
# Epoch 50/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0839 - accuracy: 0.9812 - val_loss: 1.0305 - val_accuracy: 0.5607
# Epoch 51/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.2036 - accuracy: 0.9899 - val_loss: 1.0698 - val_accuracy: 0.3295
# Epoch 52/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0275 - accuracy: 0.9913 - val_loss: 1.0638 - val_accuracy: 0.3295
# Epoch 53/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0114 - accuracy: 0.9971 - val_loss: 1.0509 - val_accuracy: 0.3295
# Epoch 54/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0301 - accuracy: 0.9884 - val_loss: 1.0947 - val_accuracy: 0.3295
# Epoch 55/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0370 - accuracy: 0.9957 - val_loss: 1.0745 - val_accuracy: 0.3295
# Epoch 56/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0313 - accuracy: 0.9942 - val_loss: 1.1941 - val_accuracy: 0.3295
# Epoch 57/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0352 - accuracy: 0.9957 - val_loss: 1.1851 - val_accuracy: 0.3295
# Epoch 58/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0446 - accuracy: 0.9942 - val_loss: 0.9728 - val_accuracy: 0.3295
# Epoch 59/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0172 - accuracy: 0.9971 - val_loss: 1.0388 - val_accuracy: 0.5607
# Epoch 60/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0519 - accuracy: 0.9913 - val_loss: 1.1089 - val_accuracy: 0.3295
# Epoch 61/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0304 - accuracy: 0.9957 - val_loss: 0.9751 - val_accuracy: 0.3295
# Epoch 62/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0737 - accuracy: 0.9899 - val_loss: 1.0696 - val_accuracy: 0.3295
# Epoch 63/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0799 - accuracy: 0.9884 - val_loss: 1.0056 - val_accuracy: 0.3295
# Epoch 64/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0758 - accuracy: 0.9913 - val_loss: 0.8680 - val_accuracy: 0.4335
# Epoch 65/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.1162 - accuracy: 0.9884 - val_loss: 0.9322 - val_accuracy: 0.5607
# Epoch 66/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.9374 - val_accuracy: 0.4046
# Epoch 67/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0363 - accuracy: 0.9913 - val_loss: 1.0098 - val_accuracy: 0.3295
# Epoch 68/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0118 - accuracy: 0.9971 - val_loss: 0.8105 - val_accuracy: 0.5607
# Epoch 69/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0263 - accuracy: 0.9928 - val_loss: 0.8831 - val_accuracy: 0.3295
# Epoch 70/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.8845 - val_accuracy: 0.3295
# Epoch 71/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.2196 - accuracy: 0.9928 - val_loss: 0.8834 - val_accuracy: 0.4913
# Epoch 72/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0611 - accuracy: 0.9870 - val_loss: 0.8446 - val_accuracy: 0.8035
# Epoch 73/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0187 - accuracy: 0.9986 - val_loss: 0.7913 - val_accuracy: 0.8960
# Epoch 74/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0351 - accuracy: 0.9928 - val_loss: 0.7707 - val_accuracy: 0.6474
# Epoch 75/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0207 - accuracy: 0.9957 - val_loss: 0.6600 - val_accuracy: 0.7977
# Epoch 76/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.7183 - val_accuracy: 0.6647
# Epoch 77/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0681 - accuracy: 0.9797 - val_loss: 0.7173 - val_accuracy: 0.5376
# Epoch 78/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0137 - accuracy: 0.9986 - val_loss: 0.6804 - val_accuracy: 0.5665
# Epoch 79/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0671 - accuracy: 0.9913 - val_loss: 0.6081 - val_accuracy: 0.6647
# Epoch 80/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.1139 - accuracy: 0.9884 - val_loss: 0.7822 - val_accuracy: 0.3757
# Epoch 81/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0271 - accuracy: 0.9942 - val_loss: 0.8013 - val_accuracy: 0.3757
# Epoch 82/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.1058 - accuracy: 0.9855 - val_loss: 0.7561 - val_accuracy: 0.6590
# Epoch 83/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0210 - accuracy: 0.9971 - val_loss: 0.5421 - val_accuracy: 0.6647
# Epoch 84/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0503 - accuracy: 0.9913 - val_loss: 0.4016 - val_accuracy: 0.8902
# Epoch 85/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0658 - accuracy: 0.9855 - val_loss: 0.4993 - val_accuracy: 1.0000
# Epoch 86/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0353 - accuracy: 0.9957 - val_loss: 0.4552 - val_accuracy: 1.0000
# Epoch 87/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0237 - accuracy: 0.9957 - val_loss: 0.4331 - val_accuracy: 1.0000
# Epoch 88/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0551 - accuracy: 0.9913 - val_loss: 0.4219 - val_accuracy: 1.0000
# Epoch 89/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0428 - accuracy: 0.9957 - val_loss: 0.3724 - val_accuracy: 1.0000
# Epoch 90/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0624 - accuracy: 0.9913 - val_loss: 0.3612 - val_accuracy: 1.0000
# Epoch 91/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0189 - accuracy: 0.9942 - val_loss: 0.2999 - val_accuracy: 1.0000
# Epoch 92/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0171 - accuracy: 0.9971 - val_loss: 0.2943 - val_accuracy: 1.0000
# Epoch 93/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.3056 - val_accuracy: 1.0000
# Epoch 94/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0190 - accuracy: 0.9971 - val_loss: 0.2789 - val_accuracy: 1.0000
# Epoch 95/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0416 - accuracy: 0.9928 - val_loss: 0.2550 - val_accuracy: 1.0000
# Epoch 96/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0281 - accuracy: 0.9957 - val_loss: 0.2450 - val_accuracy: 1.0000
# Epoch 97/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0220 - accuracy: 0.9957 - val_loss: 0.2160 - val_accuracy: 1.0000
# Epoch 98/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0255 - accuracy: 0.9942 - val_loss: 0.1767 - val_accuracy: 1.0000
# Epoch 99/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0230 - accuracy: 0.9928 - val_loss: 0.2365 - val_accuracy: 0.9711
# Epoch 100/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0126 - accuracy: 0.9971 - val_loss: 0.1981 - val_accuracy: 1.0000
# Epoch 101/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0257 - accuracy: 0.9942 - val_loss: 0.1270 - val_accuracy: 1.0000
# Epoch 102/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0622 - accuracy: 0.9884 - val_loss: 0.1559 - val_accuracy: 1.0000
# Epoch 103/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0106 - accuracy: 0.9971 - val_loss: 0.2021 - val_accuracy: 1.0000
# Epoch 104/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0251 - accuracy: 0.9971 - val_loss: 0.1679 - val_accuracy: 1.0000
# Epoch 105/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0067 - accuracy: 0.9986 - val_loss: 0.1753 - val_accuracy: 1.0000
# Epoch 106/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0192 - accuracy: 0.9957 - val_loss: 0.1462 - val_accuracy: 1.0000
# Epoch 107/200
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 1.0000
# Epoch 108/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0186 - accuracy: 0.9957 - val_loss: 0.1776 - val_accuracy: 1.0000
# Epoch 109/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0060 - accuracy: 0.9986 - val_loss: 0.1487 - val_accuracy: 1.0000
# Epoch 110/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 1.0000
# Epoch 111/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 1.0000
# Epoch 112/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0053 - accuracy: 0.9971 - val_loss: 0.0986 - val_accuracy: 1.0000
# Epoch 113/200
# 44/44 [==============================] - 1s 26ms/step - loss: 0.0965 - accuracy: 0.9870 - val_loss: 0.1123 - val_accuracy: 1.0000
# Epoch 114/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0246 - accuracy: 0.9942 - val_loss: 0.0972 - val_accuracy: 1.0000
# Epoch 115/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0236 - accuracy: 0.9957 - val_loss: 0.1156 - val_accuracy: 1.0000
# Epoch 116/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0351 - accuracy: 0.9913 - val_loss: 0.1281 - val_accuracy: 1.0000
# Epoch 117/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0278 - accuracy: 0.9957 - val_loss: 1.1450 - val_accuracy: 0.6012
# Epoch 118/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.4042 - accuracy: 0.8538 - val_loss: 1.4623 - val_accuracy: 0.3353
# Epoch 119/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.1676 - accuracy: 0.9450 - val_loss: 1.2535 - val_accuracy: 0.4277
# Epoch 120/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0710 - accuracy: 0.9812 - val_loss: 1.8406 - val_accuracy: 0.4335
# Epoch 121/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0418 - accuracy: 0.9841 - val_loss: 1.7773 - val_accuracy: 0.4393
# Epoch 122/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0787 - accuracy: 0.9768 - val_loss: 1.2489 - val_accuracy: 0.4509
# Epoch 123/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0106 - accuracy: 0.9986 - val_loss: 0.8599 - val_accuracy: 0.5665
# Epoch 124/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0199 - accuracy: 0.9986 - val_loss: 0.7771 - val_accuracy: 0.5954
# Epoch 125/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.1691 - accuracy: 0.9580 - val_loss: 1.6265 - val_accuracy: 0.5318
# Epoch 126/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0653 - accuracy: 0.9855 - val_loss: 0.8394 - val_accuracy: 0.5896
# Epoch 127/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0557 - accuracy: 0.9884 - val_loss: 0.4940 - val_accuracy: 0.7168
# Epoch 128/200
# 44/44 [==============================] - -0s -3814us/step - loss: 0.0426 - accuracy: 0.9942 - val_loss: 0.4015 - val_accuracy: 0.7630
# Epoch 129/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0250 - accuracy: 0.9957 - val_loss: 0.4775 - val_accuracy: 0.7630
# Epoch 130/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0599 - accuracy: 0.9913 - val_loss: 0.4606 - val_accuracy: 0.7746
# Epoch 131/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0353 - accuracy: 0.9942 - val_loss: 0.6147 - val_accuracy: 0.7746
# Epoch 132/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0177 - accuracy: 0.9957 - val_loss: 0.5541 - val_accuracy: 0.7746
# Epoch 133/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0379 - accuracy: 0.9942 - val_loss: 0.8798 - val_accuracy: 0.7746
# Epoch 134/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0562 - accuracy: 0.9855 - val_loss: 0.6178 - val_accuracy: 0.7688
# Epoch 135/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0596 - accuracy: 0.9899 - val_loss: 0.0945 - val_accuracy: 1.0000
# Epoch 136/200
# 44/44 [==============================] - 1s 22ms/step - loss: 0.0281 - accuracy: 0.9913 - val_loss: 0.1781 - val_accuracy: 0.9017
# Epoch 137/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0416 - accuracy: 0.9870 - val_loss: 0.1096 - val_accuracy: 1.0000
# Epoch 138/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0176 - accuracy: 0.9971 - val_loss: 0.1407 - val_accuracy: 0.9595
# Epoch 139/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0946 - accuracy: 0.9884 - val_loss: 0.1749 - val_accuracy: 0.9075
# Epoch 140/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 0.1562 - val_accuracy: 0.9249
# Epoch 141/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0113 - accuracy: 0.9971 - val_loss: 0.1338 - val_accuracy: 0.9480
# Epoch 142/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0159 - accuracy: 0.9957 - val_loss: 0.0803 - val_accuracy: 1.0000
# Epoch 143/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0190 - accuracy: 0.9928 - val_loss: 0.1333 - val_accuracy: 0.9711
# Epoch 144/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0161 - accuracy: 0.9957 - val_loss: 0.1027 - val_accuracy: 0.9942
# Epoch 145/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0157 - accuracy: 0.9957 - val_loss: 0.0559 - val_accuracy: 1.0000
# Epoch 146/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0165 - accuracy: 0.9957 - val_loss: 0.0800 - val_accuracy: 1.0000
# Epoch 147/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0213 - accuracy: 0.9971 - val_loss: 0.1616 - val_accuracy: 0.9133
# Epoch 148/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0210 - accuracy: 0.9942 - val_loss: 0.0566 - val_accuracy: 1.0000
# Epoch 149/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 1.0000
# Epoch 150/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.0503 - val_accuracy: 1.0000
# Epoch 151/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0031 - accuracy: 0.9986 - val_loss: 0.0339 - val_accuracy: 1.0000
# Epoch 152/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0415 - accuracy: 0.9884 - val_loss: 0.0339 - val_accuracy: 0.9942
# Epoch 153/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0197 - accuracy: 0.9942 - val_loss: 0.0565 - val_accuracy: 1.0000
# Epoch 154/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0091 - accuracy: 0.9986 - val_loss: 0.0584 - val_accuracy: 1.0000
# Epoch 155/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0929 - val_accuracy: 1.0000
# Epoch 156/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0169 - accuracy: 0.9986 - val_loss: 0.0483 - val_accuracy: 1.0000
# Epoch 157/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0142 - accuracy: 0.9971 - val_loss: 0.0295 - val_accuracy: 1.0000
# Epoch 158/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0152 - accuracy: 0.9957 - val_loss: 0.0426 - val_accuracy: 1.0000
# Epoch 159/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0229 - accuracy: 0.9957 - val_loss: 0.1199 - val_accuracy: 0.9711
# Epoch 160/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0240 - accuracy: 0.9957 - val_loss: 0.0638 - val_accuracy: 0.9884
# Epoch 161/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0205 - accuracy: 0.9971 - val_loss: 0.0394 - val_accuracy: 1.0000
# Epoch 162/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0087 - accuracy: 0.9986 - val_loss: 0.0346 - val_accuracy: 1.0000
# Epoch 163/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.0256 - val_accuracy: 1.0000
# Epoch 164/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 165/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0062 - accuracy: 0.9971 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 166/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0130 - accuracy: 0.9957 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 167/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0999 - accuracy: 0.9884 - val_loss: 0.0453 - val_accuracy: 1.0000
# Epoch 168/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0116 - accuracy: 0.9971 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 169/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 1.0000
# Epoch 170/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 171/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0044 - accuracy: 0.9971 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 172/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0227 - accuracy: 0.9957 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 173/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0081 - accuracy: 0.9986 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 174/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 175/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 176/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0452 - accuracy: 0.9957 - val_loss: 0.0503 - val_accuracy: 0.9942
# Epoch 177/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0230 - accuracy: 0.9957 - val_loss: 0.0421 - val_accuracy: 1.0000
# Epoch 178/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0263 - accuracy: 0.9913 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 179/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0186 - accuracy: 0.9957 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 180/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 181/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 182/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 183/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 184/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0546 - accuracy: 0.9942 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 185/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0195 - accuracy: 0.9957 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 186/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0191 - accuracy: 0.9971 - val_loss: 1.7008 - val_accuracy: 0.8613
# Epoch 187/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.8007 - accuracy: 0.7800 - val_loss: 2.8167 - val_accuracy: 0.3121
# Epoch 188/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.1821 - accuracy: 0.9436 - val_loss: 2.6213 - val_accuracy: 0.3237
# Epoch 189/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0886 - accuracy: 0.9725 - val_loss: 2.2110 - val_accuracy: 0.3295
# Epoch 190/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0855 - accuracy: 0.9725 - val_loss: 2.1588 - val_accuracy: 0.4104
# Epoch 191/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0540 - accuracy: 0.9783 - val_loss: 1.4326 - val_accuracy: 0.5549
# Epoch 192/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0416 - accuracy: 0.9870 - val_loss: 0.8624 - val_accuracy: 0.7457
# Epoch 193/200
# 44/44 [==============================] - 1s 25ms/step - loss: 0.0621 - accuracy: 0.9783 - val_loss: 0.7794 - val_accuracy: 0.7688
# Epoch 194/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0587 - accuracy: 0.9855 - val_loss: 0.6917 - val_accuracy: 0.7688
# Epoch 195/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0511 - accuracy: 0.9855 - val_loss: 0.3281 - val_accuracy: 0.8728
# Epoch 196/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0588 - accuracy: 0.9841 - val_loss: 0.3956 - val_accuracy: 0.8324
# Epoch 197/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0221 - accuracy: 0.9942 - val_loss: 0.5156 - val_accuracy: 0.7919
# Epoch 198/200
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0240 - accuracy: 0.9942 - val_loss: 0.5238 - val_accuracy: 0.8092
# Epoch 199/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0887 - accuracy: 0.9826 - val_loss: 0.5706 - val_accuracy: 0.8671
# Epoch 200/200
# 44/44 [==============================] - 1s 23ms/step - loss: 0.1377 - accuracy: 0.9754 - val_loss: 0.7236 - val_accuracy: 0.8092
# Training time: 214.1 sec
# Score for train dataset
# 22/22 [==============================] - 1s 20ms/step - loss: 0.7727 - accuracy: 0.8480
# Score:
# loss : 0.7726590633392334
# loss : 84.80463027954102 %

# %%
def plotHistory(history, train, validation):
    """
        plot training history
        Parameters
        ------------------------------
        history = history
        train = 'accuracy' or 'loss'
        validation = 'val_accuracy' or 'val_loss'
    """
    plt.figure(figsize= (8, 6))
    plt.plot(history.history[train])
    plt.plot(history.history[validation])
    plt.legend(['train', 'validation'], loc= 'center right')
    plt.xlabel("Epochs")
    if train == 'accuracy':
        plt.ylabel("Accuracy")
        plt.title(f"Accuracy for train dataset")
    elif train == "loss":
        plt.ylabel("Loss")
        plt.title("Loss for train dataset")
    plt.show()

# %%
plotHistory(history= history, train= 'accuracy', validation= 'val_accuracy')
plotHistory(history= history, train= 'loss', validation= 'val_loss')

# %%
# Prediction for test dataset

prediction = model.predict(X_test)
predictionClass = np.argmax(prediction, axis= 1)        # One-hot encoding --> Original label

# Actual Class (One-hot encoding testTarget --> y_test)
if testTargets.ndim > 1:
    actualClass = np.argmax(testTargets, axis= 1)
else:
    actualClass = testTargets

# Classification report
print(f"Classification report: \n{classification_report(actualClass, predictionClass)}")

# Confusion matrix
plt.figure(figsize= (8, 6))
sns.heatmap(confusion_matrix(actualClass, predictionClass), 
            annot= True, 
            fmt= "d", 
            cmap= "Blues",
            cbar= False)
plt.title("Confusion matrix for test dataset")
plt.xlabel("Prediction class")
plt.ylabel("Actual class")
plt.show()
# Out:
# 7/7 [==============================] - 1s 51ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.76      0.87        72
#            1       0.83      1.00      0.91        72
#            2       0.77      0.79      0.78        72
#
#     accuracy                           0.85       216
#    macro avg       0.87      0.85      0.85       216
# weighted avg       0.87      0.85      0.85       216

# %%
# Prediction for 1 image

randomImgIdx = random.randrange(0, X_test.shape[0])

predictStartTime = time.time()

predictionImg = X_test[randomImgIdx]
predictionImg = np.expand_dims(predictionImg, axis= 0)

testPrediction = model.predict(predictionImg)

predictEndTime = time.time()

print("Random image index: ", randomImgIdx)
print("Random actual label: ", i_test[randomImgIdx])
print("Random actual class: ", actualClass[randomImgIdx])
print("Random prediction class: ", predictionClass[randomImgIdx])
# Out:
# 1/1 [==============================] - 0s 255ms/step
# Random image index:  156
# Random actual label:  I_313
# Random actual class:  0
# Random prediction class:  0
