# %%
import os
import glob
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import keras
import tensorflow as tf
from keras import optimizers
from keras.utils import to_categorical
from keras.layers import Dense, Input
from keras.models import Model, load_model
from keras.applications import MobileNetV2
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
dataPath = "../1_Data_Preprocessing/16Sample/4Class/GADF_4Class_16Sample.npz"
data = np.load(dataPath)

X_data = data['X_data']
y_data = data['y_data']
i_data = data['i_data']

data.close()

print("X_data: ", X_data.shape)
print("y_data: ", y_data.shape)
print("i_data: ", i_data.shape)
# Out:
# X_data:  (2880, 16, 16, 3)
# y_data:  (2880,)
# i_data:  (2880,)

# %%
# Data split

# Set random seed for reproductivity
seed = 42

# Train - Test split
X_train, X_test, y_train, y_test, i_train, i_test = train_test_split(X_data, y_data, i_data, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_data)

# Train - Validation split
X_train, X_val, y_train, y_val, i_train, i_val = train_test_split(X_train, y_train, i_train, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_train)

print(X_train.shape, X_test.shape, X_val.shape)
print(y_train.shape, y_test.shape, y_val.shape)
print(i_train.shape, i_test.shape, i_val.shape)

print(np.unique(y_train, return_counts= True))
print(np.unique(y_test, return_counts= True))
print(np.unique(y_val, return_counts= True))
# Out:
# (1843, 16, 16, 3) (576, 16, 16, 3) (461, 16, 16, 3)
# (1843,) (576,) (461,)
# (1843,) (576,) (461,)
# (array([0, 1, 2, 3]), array([461, 461, 460, 461], dtype=int64))
# (array([0, 1, 2, 3]), array([144, 144, 144, 144], dtype=int64))
# (array([0, 1, 2, 3]), array([115, 115, 116, 115], dtype=int64))

# %%
# One - hot encoding
trainTargets = to_categorical(y_train)
testTargets = to_categorical(y_test)
valTargets = to_categorical(y_val)

print("Train targets: ", trainTargets.shape)
print("Test targets: ", testTargets.shape)
print("Validation targets: ", valTargets.shape)
# Out:
# Train targets:  (1843, 4)
# Test targets:  (576, 4)
# Validation targets:  (461, 4)

# %%
weightPath = "./weights/"

# %%
# MobileNetV2 Transfer-learning
# Import convolution layer
# weight = None

with tf.device("/device:GPU:0"):
    inputTensor = Input(shape= (16, 16, 3))

    model = MobileNetV2(input_tensor= inputTensor,              # Input data shape
                        include_top= False,                     # Only convolution layer. If True: Use Classification layer
                        weights= None,                          # If weights= "imagenet" --> Use imagenet weights
                        pooling= 'max')

    x = model.output
    x = Dense(4, activation= 'softmax', kernel_initializer= 'he_normal')(x)

    model = Model(model.input, x)

    # Instantiate optimizer
    optim = optimizers.SGD(learning_rate= 0.01,
                           decay= 1e-3,
                           momentum= 0.9,
                           nesterov= True)

    # Compile model
    model.compile(optimizer= optim,
                  loss= 'categorical_crossentropy',
                  metrics= ['accuracy'])

    print("Training======================================")
    startTime = time.time()                                     # Training start time

    history = model.fit(X_train, trainTargets,
                        batch_size= 16,
                        epochs= 150,
                        verbose= 1,
                        validation_data= (X_val, valTargets)
                        )
    
    endTime = time.time()                                       # Training end time
    print(f"Training time: {np.round(endTime - startTime, 3)} sec")

    # save weight file
    model.save(os.path.join(weightPath, "GADF_MobileNetV2_4Class_16Sample.h5"))

    # Evaluate for total train dataset
    print("Score for train dataset")
    score = model.evaluate(X_train, trainTargets, verbose= 1)
    print(f"Score: \n{model.metrics_names[0]} : {score[0]}\n{model.metrics_names[0]} : {score[1] * 100} %")
# Out:
# Training======================================
# Epoch 1/150
# 116/116 [==============================] - 10s 37ms/step - loss: 1.2963 - accuracy: 0.6093 - val_loss: 1.4135 - val_accuracy: 0.2495
# Epoch 2/150
# 116/116 [==============================] - 3s 23ms/step - loss: 1.0566 - accuracy: 0.6413 - val_loss: 1.4160 - val_accuracy: 0.2495
# Epoch 3/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.5150 - accuracy: 0.8372 - val_loss: 1.4210 - val_accuracy: 0.2495
# Epoch 4/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.3036 - accuracy: 0.9170 - val_loss: 1.4455 - val_accuracy: 0.2495
# Epoch 5/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.2658 - accuracy: 0.9360 - val_loss: 1.4325 - val_accuracy: 0.2495
# Epoch 6/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1910 - accuracy: 0.9582 - val_loss: 1.4551 - val_accuracy: 0.2495
# Epoch 7/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.1234 - accuracy: 0.9729 - val_loss: 1.4478 - val_accuracy: 0.2495
# Epoch 8/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0952 - accuracy: 0.9799 - val_loss: 1.4606 - val_accuracy: 0.2495
# Epoch 9/150
# 116/116 [==============================] - 2s 22ms/step - loss: 0.1659 - accuracy: 0.9723 - val_loss: 1.4739 - val_accuracy: 0.2495
# Epoch 10/150
# 116/116 [==============================] - 2s 21ms/step - loss: 0.1047 - accuracy: 0.9772 - val_loss: 1.5574 - val_accuracy: 0.2495
# Epoch 11/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.2666 - accuracy: 0.9316 - val_loss: 1.5325 - val_accuracy: 0.2495
# Epoch 12/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1621 - accuracy: 0.9528 - val_loss: 1.5811 - val_accuracy: 0.3189
# Epoch 13/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.2038 - accuracy: 0.9566 - val_loss: 1.6014 - val_accuracy: 0.2495
# Epoch 14/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0592 - accuracy: 0.9837 - val_loss: 1.6951 - val_accuracy: 0.2495
# Epoch 15/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1560 - accuracy: 0.9674 - val_loss: 1.4657 - val_accuracy: 0.2495
# Epoch 16/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0671 - accuracy: 0.9886 - val_loss: 1.5863 - val_accuracy: 0.2495
# Epoch 17/150
# 116/116 [==============================] - 3s 25ms/step - loss: 0.0462 - accuracy: 0.9908 - val_loss: 1.4938 - val_accuracy: 0.2495
# Epoch 18/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0635 - accuracy: 0.9902 - val_loss: 1.6215 - val_accuracy: 0.2755
# Epoch 19/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.1264 - accuracy: 0.9631 - val_loss: 1.5434 - val_accuracy: 0.4989
# Epoch 20/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1490 - accuracy: 0.9680 - val_loss: 1.5510 - val_accuracy: 0.3471
# Epoch 21/150
# 116/116 [==============================] - 3s 22ms/step - loss: 0.0282 - accuracy: 0.9935 - val_loss: 1.5926 - val_accuracy: 0.3297
# Epoch 22/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0203 - accuracy: 0.9957 - val_loss: 1.5587 - val_accuracy: 0.3709
# Epoch 23/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0673 - accuracy: 0.9864 - val_loss: 1.4870 - val_accuracy: 0.2495
# Epoch 24/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0159 - accuracy: 0.9957 - val_loss: 1.4819 - val_accuracy: 0.2495
# Epoch 25/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0598 - accuracy: 0.9891 - val_loss: 1.4334 - val_accuracy: 0.2495
# Epoch 26/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0132 - accuracy: 0.9973 - val_loss: 1.4383 - val_accuracy: 0.2495
# Epoch 27/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0358 - accuracy: 0.9946 - val_loss: 1.4679 - val_accuracy: 0.2907
# Epoch 28/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0724 - accuracy: 0.9886 - val_loss: 1.4435 - val_accuracy: 0.2495
# Epoch 29/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0731 - accuracy: 0.9821 - val_loss: 1.3991 - val_accuracy: 0.2993
# Epoch 30/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0430 - accuracy: 0.9919 - val_loss: 1.3639 - val_accuracy: 0.4642
# Epoch 31/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0559 - accuracy: 0.9870 - val_loss: 1.2764 - val_accuracy: 0.4989
# Epoch 32/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0230 - accuracy: 0.9957 - val_loss: 1.2529 - val_accuracy: 0.4577
# Epoch 33/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0460 - accuracy: 0.9881 - val_loss: 1.4147 - val_accuracy: 0.2495
# Epoch 34/150
# 116/116 [==============================] - 3s 22ms/step - loss: 0.5608 - accuracy: 0.8405 - val_loss: 1.9388 - val_accuracy: 0.2495
# Epoch 35/150
# 116/116 [==============================] - 3s 22ms/step - loss: 0.2773 - accuracy: 0.9116 - val_loss: 1.6085 - val_accuracy: 0.3102
# Epoch 36/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1570 - accuracy: 0.9495 - val_loss: 1.5625 - val_accuracy: 0.4143
# Epoch 37/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.1230 - accuracy: 0.9674 - val_loss: 1.4629 - val_accuracy: 0.3406
# Epoch 38/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0949 - accuracy: 0.9712 - val_loss: 1.4348 - val_accuracy: 0.3948
# Epoch 39/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0955 - accuracy: 0.9805 - val_loss: 1.2925 - val_accuracy: 0.4555
# Epoch 40/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0613 - accuracy: 0.9821 - val_loss: 1.2329 - val_accuracy: 0.4599
# Epoch 41/150
# 116/116 [==============================] - 3s 22ms/step - loss: 0.0599 - accuracy: 0.9870 - val_loss: 1.2797 - val_accuracy: 0.4794
# Epoch 42/150
# 116/116 [==============================] - 2s 21ms/step - loss: 0.1208 - accuracy: 0.9750 - val_loss: 1.2931 - val_accuracy: 0.4989
# Epoch 43/150
# 116/116 [==============================] - 3s 22ms/step - loss: 0.0515 - accuracy: 0.9881 - val_loss: 1.1744 - val_accuracy: 0.4967
# Epoch 44/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0423 - accuracy: 0.9929 - val_loss: 0.9843 - val_accuracy: 0.5445
# Epoch 45/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0416 - accuracy: 0.9902 - val_loss: 0.7911 - val_accuracy: 0.6963
# Epoch 46/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1049 - accuracy: 0.9723 - val_loss: 0.7118 - val_accuracy: 0.6985
# Epoch 47/150
# 116/116 [==============================] - 3s 22ms/step - loss: 0.0244 - accuracy: 0.9929 - val_loss: 0.6847 - val_accuracy: 0.7180
# Epoch 48/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0374 - accuracy: 0.9940 - val_loss: 0.6264 - val_accuracy: 0.7440
# Epoch 49/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0268 - accuracy: 0.9940 - val_loss: 0.5444 - val_accuracy: 0.7983
# Epoch 50/150
# 116/116 [==============================] - 3s 22ms/step - loss: 0.0307 - accuracy: 0.9919 - val_loss: 0.4855 - val_accuracy: 0.8612
# Epoch 51/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0369 - accuracy: 0.9913 - val_loss: 0.4822 - val_accuracy: 0.8330
# Epoch 52/150
# 116/116 [==============================] - 3s 22ms/step - loss: 0.0229 - accuracy: 0.9957 - val_loss: 0.4217 - val_accuracy: 0.8829
# Epoch 53/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0544 - accuracy: 0.9881 - val_loss: 0.3749 - val_accuracy: 0.9653
# Epoch 54/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0376 - accuracy: 0.9913 - val_loss: 0.4993 - val_accuracy: 0.8113
# Epoch 55/150
# 116/116 [==============================] - 3s 22ms/step - loss: 0.0306 - accuracy: 0.9913 - val_loss: 0.7724 - val_accuracy: 0.8330
# Epoch 56/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.8692 - accuracy: 0.6815 - val_loss: 1.2709 - val_accuracy: 0.4577
# Epoch 57/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.6387 - accuracy: 0.7249 - val_loss: 1.3212 - val_accuracy: 0.4555
# Epoch 58/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.4365 - accuracy: 0.8226 - val_loss: 0.9723 - val_accuracy: 0.5640
# Epoch 59/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.3906 - accuracy: 0.8378 - val_loss: 0.7371 - val_accuracy: 0.7505
# Epoch 60/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.3108 - accuracy: 0.8709 - val_loss: 0.6448 - val_accuracy: 0.7484
# Epoch 61/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.2997 - accuracy: 0.8899 - val_loss: 0.7253 - val_accuracy: 0.6985
# Epoch 62/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.1799 - accuracy: 0.9409 - val_loss: 0.6044 - val_accuracy: 0.7722
# Epoch 63/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1572 - accuracy: 0.9457 - val_loss: 0.4681 - val_accuracy: 0.8091
# Epoch 64/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.1837 - accuracy: 0.9316 - val_loss: 0.3614 - val_accuracy: 0.8547
# Epoch 65/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.1964 - accuracy: 0.9387 - val_loss: 0.3611 - val_accuracy: 0.8525
# Epoch 66/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.1550 - accuracy: 0.9495 - val_loss: 0.3088 - val_accuracy: 0.9067
# Epoch 67/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.1350 - accuracy: 0.9582 - val_loss: 0.3643 - val_accuracy: 0.8633
# Epoch 68/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.1965 - accuracy: 0.9495 - val_loss: 0.3862 - val_accuracy: 0.8764
# Epoch 69/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0922 - accuracy: 0.9674 - val_loss: 0.2107 - val_accuracy: 0.9501
# Epoch 70/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0915 - accuracy: 0.9712 - val_loss: 0.1694 - val_accuracy: 0.9523
# Epoch 71/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0866 - accuracy: 0.9740 - val_loss: 0.1590 - val_accuracy: 0.9783
# Epoch 72/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0670 - accuracy: 0.9826 - val_loss: 0.1524 - val_accuracy: 0.9978
# Epoch 73/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0851 - accuracy: 0.9740 - val_loss: 0.1486 - val_accuracy: 0.9588
# Epoch 74/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0608 - accuracy: 0.9837 - val_loss: 0.1303 - val_accuracy: 0.9610
# Epoch 75/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0608 - accuracy: 0.9810 - val_loss: 0.0995 - val_accuracy: 1.0000
# Epoch 76/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0399 - accuracy: 0.9881 - val_loss: 0.0697 - val_accuracy: 0.9978
# Epoch 77/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0606 - accuracy: 0.9848 - val_loss: 0.0821 - val_accuracy: 1.0000
# Epoch 78/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0386 - accuracy: 0.9886 - val_loss: 0.0836 - val_accuracy: 0.9978
# Epoch 79/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0461 - accuracy: 0.9859 - val_loss: 0.1748 - val_accuracy: 0.9393
# Epoch 80/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0723 - accuracy: 0.9826 - val_loss: 0.1453 - val_accuracy: 0.9913
# Epoch 81/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0566 - accuracy: 0.9848 - val_loss: 0.0858 - val_accuracy: 0.9978
# Epoch 82/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0327 - accuracy: 0.9897 - val_loss: 0.0800 - val_accuracy: 1.0000
# Epoch 83/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0545 - accuracy: 0.9826 - val_loss: 0.1229 - val_accuracy: 0.9588
# Epoch 84/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0682 - accuracy: 0.9837 - val_loss: 0.0876 - val_accuracy: 0.9978
# Epoch 85/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0365 - accuracy: 0.9902 - val_loss: 0.0770 - val_accuracy: 0.9978
# Epoch 86/150
# 116/116 [==============================] - 2s 21ms/step - loss: 0.0636 - accuracy: 0.9816 - val_loss: 0.1084 - val_accuracy: 0.9978
# Epoch 87/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0669 - accuracy: 0.9816 - val_loss: 0.2005 - val_accuracy: 0.9328
# Epoch 88/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.3538 - accuracy: 0.8752 - val_loss: 0.6295 - val_accuracy: 0.7354
# Epoch 89/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.2038 - accuracy: 0.9295 - val_loss: 0.5802 - val_accuracy: 0.7744
# Epoch 90/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1598 - accuracy: 0.9436 - val_loss: 0.3967 - val_accuracy: 0.8764
# Epoch 91/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0787 - accuracy: 0.9761 - val_loss: 0.2387 - val_accuracy: 0.9631
# Epoch 92/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0785 - accuracy: 0.9740 - val_loss: 0.2753 - val_accuracy: 0.9176
# Epoch 93/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.1232 - accuracy: 0.9626 - val_loss: 0.2452 - val_accuracy: 0.9544
# Epoch 94/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0594 - accuracy: 0.9805 - val_loss: 0.1370 - val_accuracy: 0.9848
# Epoch 95/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0695 - accuracy: 0.9826 - val_loss: 0.1550 - val_accuracy: 0.9718
# Epoch 96/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0400 - accuracy: 0.9864 - val_loss: 0.1412 - val_accuracy: 0.9892
# Epoch 97/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0924 - accuracy: 0.9783 - val_loss: 0.1754 - val_accuracy: 0.9544
# Epoch 98/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0974 - accuracy: 0.9734 - val_loss: 0.2739 - val_accuracy: 0.8590
# Epoch 99/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0768 - accuracy: 0.9778 - val_loss: 0.2407 - val_accuracy: 0.9414
# Epoch 100/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0595 - accuracy: 0.9837 - val_loss: 0.1883 - val_accuracy: 0.9653
# Epoch 101/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0359 - accuracy: 0.9897 - val_loss: 0.1260 - val_accuracy: 0.9805
# Epoch 102/150
# 116/116 [==============================] - 3s 22ms/step - loss: 0.0498 - accuracy: 0.9859 - val_loss: 0.1236 - val_accuracy: 0.9935
# Epoch 103/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0447 - accuracy: 0.9875 - val_loss: 0.0885 - val_accuracy: 0.9913
# Epoch 104/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0698 - accuracy: 0.9788 - val_loss: 0.1084 - val_accuracy: 0.9978
# Epoch 105/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0396 - accuracy: 0.9881 - val_loss: 0.0673 - val_accuracy: 0.9978
# Epoch 106/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0509 - accuracy: 0.9837 - val_loss: 0.0680 - val_accuracy: 0.9978
# Epoch 107/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0606 - accuracy: 0.9837 - val_loss: 0.0496 - val_accuracy: 0.9978
# Epoch 108/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0415 - accuracy: 0.9875 - val_loss: 0.0349 - val_accuracy: 1.0000
# Epoch 109/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0495 - accuracy: 0.9859 - val_loss: 0.0662 - val_accuracy: 1.0000
# Epoch 110/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0435 - accuracy: 0.9864 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 111/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0347 - accuracy: 0.9913 - val_loss: 0.0545 - val_accuracy: 0.9978
# Epoch 112/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0805 - accuracy: 0.9761 - val_loss: 0.1724 - val_accuracy: 0.9566
# Epoch 113/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0555 - accuracy: 0.9837 - val_loss: 0.1183 - val_accuracy: 0.9696
# Epoch 114/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0328 - accuracy: 0.9919 - val_loss: 0.0909 - val_accuracy: 0.9761
# Epoch 115/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0546 - accuracy: 0.9864 - val_loss: 0.1092 - val_accuracy: 0.9826
# Epoch 116/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0405 - accuracy: 0.9853 - val_loss: 0.0720 - val_accuracy: 0.9957
# Epoch 117/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0365 - accuracy: 0.9870 - val_loss: 0.0642 - val_accuracy: 0.9957
# Epoch 118/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0397 - accuracy: 0.9864 - val_loss: 0.0589 - val_accuracy: 0.9957
# Epoch 119/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0189 - accuracy: 0.9935 - val_loss: 0.0333 - val_accuracy: 0.9978
# Epoch 120/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0484 - accuracy: 0.9859 - val_loss: 0.0810 - val_accuracy: 0.9848
# Epoch 121/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0258 - accuracy: 0.9913 - val_loss: 0.0351 - val_accuracy: 0.9978
# Epoch 122/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0276 - accuracy: 0.9924 - val_loss: 0.0279 - val_accuracy: 0.9978
# Epoch 123/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0132 - accuracy: 0.9967 - val_loss: 0.0493 - val_accuracy: 0.9978
# Epoch 124/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0346 - accuracy: 0.9897 - val_loss: 0.0518 - val_accuracy: 0.9978
# Epoch 125/150
# 116/116 [==============================] - 3s 22ms/step - loss: 0.0376 - accuracy: 0.9902 - val_loss: 0.0773 - val_accuracy: 0.9978
# Epoch 126/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0465 - accuracy: 0.9886 - val_loss: 0.0626 - val_accuracy: 0.9978
# Epoch 127/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0210 - accuracy: 0.9946 - val_loss: 0.0470 - val_accuracy: 0.9978
# Epoch 128/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0372 - accuracy: 0.9924 - val_loss: 0.0845 - val_accuracy: 0.9957
# Epoch 129/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0162 - accuracy: 0.9957 - val_loss: 0.1886 - val_accuracy: 0.9046
# Epoch 130/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0276 - accuracy: 0.9929 - val_loss: 0.0786 - val_accuracy: 0.9957
# Epoch 131/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0395 - accuracy: 0.9891 - val_loss: 0.0700 - val_accuracy: 0.9978
# Epoch 132/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0204 - accuracy: 0.9946 - val_loss: 0.0635 - val_accuracy: 0.9978
# Epoch 133/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0150 - accuracy: 0.9962 - val_loss: 0.0655 - val_accuracy: 0.9957
# Epoch 134/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0278 - accuracy: 0.9924 - val_loss: 0.0547 - val_accuracy: 1.0000
# Epoch 135/150
# 116/116 [==============================] - 2s 21ms/step - loss: 0.0310 - accuracy: 0.9913 - val_loss: 0.1494 - val_accuracy: 0.9436
# Epoch 136/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0717 - accuracy: 0.9772 - val_loss: 0.1976 - val_accuracy: 0.9241
# Epoch 137/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0386 - accuracy: 0.9875 - val_loss: 0.0552 - val_accuracy: 0.9826
# Epoch 138/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0358 - accuracy: 0.9875 - val_loss: 0.0516 - val_accuracy: 0.9870
# Epoch 139/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0141 - accuracy: 0.9973 - val_loss: 0.0379 - val_accuracy: 0.9957
# Epoch 140/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0476 - accuracy: 0.9859 - val_loss: 0.0645 - val_accuracy: 0.9913
# Epoch 141/150
# 116/116 [==============================] - 3s 22ms/step - loss: 0.0395 - accuracy: 0.9897 - val_loss: 0.0569 - val_accuracy: 0.9978
# Epoch 142/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0429 - accuracy: 0.9886 - val_loss: 0.0609 - val_accuracy: 1.0000
# Epoch 143/150
# 116/116 [==============================] - 3s 25ms/step - loss: 0.0304 - accuracy: 0.9902 - val_loss: 0.0358 - val_accuracy: 1.0000
# Epoch 144/150
# 116/116 [==============================] - 3s 28ms/step - loss: 0.0128 - accuracy: 0.9946 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 145/150
# 116/116 [==============================] - 3s 26ms/step - loss: 0.0367 - accuracy: 0.9881 - val_loss: 0.0366 - val_accuracy: 0.9935
# Epoch 146/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0328 - accuracy: 0.9913 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 147/150
# 116/116 [==============================] - 3s 23ms/step - loss: 0.0731 - accuracy: 0.9875 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 148/150
# 116/116 [==============================] - 3s 24ms/step - loss: 0.0430 - accuracy: 0.9864 - val_loss: 0.0492 - val_accuracy: 0.9978
# Epoch 149/150
# 116/116 [==============================] - 3s 25ms/step - loss: 0.0185 - accuracy: 0.9973 - val_loss: 0.0428 - val_accuracy: 0.9892
# Epoch 150/150
# 116/116 [==============================] - 3s 26ms/step - loss: 0.0175 - accuracy: 0.9951 - val_loss: 0.0335 - val_accuracy: 0.9935
# Training time: 413.905 sec
# Score for train dataset
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0302 - accuracy: 0.9978
# Score:
# loss : 0.030156733468174934
# loss : 99.78296160697937 %

# %%
def plotHistory(history, train, validation):
    """
        plot training history
        Parameters
        ------------------------------
        history = history
        train = 'accuracy' or 'loss'
        validation = 'val_accuracy' or 'val_loss'
    """
    plt.figure(figsize= (8, 6))
    plt.plot(history.history[train])
    plt.plot(history.history[validation])
    plt.legend(['train', 'validation'], loc= 'center right')
    plt.xlabel("Epochs")
    if train == 'accuracy':
        plt.ylabel("Accuracy")
        plt.title(f"Accuracy for train dataset")
    elif train == "loss":
        plt.ylabel("Loss")
        plt.title("Loss for train dataset")
    plt.show()

# %%
plotHistory(history= history, train= 'accuracy', validation= 'val_accuracy')
plotHistory(history= history, train= 'loss', validation= 'val_loss')

# %%
# Evaluate test dataset
testScore = model.evaluate(X_test, testTargets, verbose= 1)
print(f"{model.metrics_names[0]} : {testScore[0]}\n{model.metrics_names[1]} : {testScore[1] * 100} %")
# Out:
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0440 - accuracy: 0.9913
# loss : 0.04401887580752373
# accuracy : 99.13194179534912 %

# %%
# Prediction for test dataset

prediction = model.predict(X_test)
predictionClass = np.argmax(prediction, axis= 1)        # One-hot encoding --> Original label

# Actual Class (One-hot encoding testTarget --> y_test)
if testTargets.ndim > 1:
    actualClass = np.argmax(testTargets, axis= 1)
else:
    actualClass = testTargets

# Classification report
print(f"Classification report: \n{classification_report(actualClass, predictionClass)}")

# Confusion matrix
plt.figure(figsize= (8, 6))
sns.heatmap(confusion_matrix(actualClass, predictionClass), 
            annot= True, 
            fmt= "d", 
            cmap= "Blues",
            cbar= False)
plt.title("Confusion matrix for test dataset")
plt.xlabel("Prediction class")
plt.ylabel("Actual class")
plt.show()
# Out:
# 18/18 [==============================] - 1s 7ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       144
#            1       1.00      1.00      1.00       144
#            2       0.97      1.00      0.98       144
#            3       1.00      0.97      0.98       144
#
#     accuracy                           0.99       576
#    macro avg       0.99      0.99      0.99       576
# weighted avg       0.99      0.99      0.99       576

# %%
# Prediction for 1 image

randomImgIdx = random.randrange(0, X_test.shape[0])

predictStartTime = time.time()

predictionImg = X_test[randomImgIdx]
predictionImg = np.expand_dims(predictionImg, axis= 0)

testPrediction = model.predict(predictionImg)

predictEndTime = time.time()

print("Random image index: ", randomImgIdx)
print("Random actual label: ", i_test[randomImgIdx])
print("Random actual class: ", actualClass[randomImgIdx])
print("Random prediction class: ", predictionClass[randomImgIdx])
# Out:
# 1/1 [==============================] - 1s 892ms/step
# Random image index:  324
# Random actual label:  R_508
# Random actual class:  3
# Random prediction class:  3
