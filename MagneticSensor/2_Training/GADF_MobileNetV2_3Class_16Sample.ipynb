# %%
import os
import glob
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import keras
import tensorflow as tf
from keras import optimizers
from keras.utils import to_categorical
from keras.layers import Dense, Input
from keras.models import Model, load_model
from keras.applications import MobileNetV2
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
dataPath = "../1_Data_Preprocessing/16Sample/3Class/GADF_3Class_16Sample.npz"
data = np.load(dataPath)

X_data = data['X_data']
y_data = data['y_data']
i_data = data['i_data']

data.close()

print("X_data: ", X_data.shape)
print("y_data: ", y_data.shape)
print("i_data: ", i_data.shape)
# Out:
# X_data:  (2160, 16, 16, 3)
# y_data:  (2160,)
# i_data:  (2160,)

# %%
# Data split

# Set random seed for reproductivity
seed = 42

# Train - Test split
X_train, X_test, y_train, y_test, i_train, i_test = train_test_split(X_data, y_data, i_data, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_data)

# Train - Validation split
X_train, X_val, y_train, y_val, i_train, i_val = train_test_split(X_train, y_train, i_train, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_train)

print(X_train.shape, X_test.shape, X_val.shape)
print(y_train.shape, y_test.shape, y_val.shape)
print(i_train.shape, i_test.shape, i_val.shape)

print(np.unique(y_train, return_counts= True))
print(np.unique(y_test, return_counts= True))
print(np.unique(y_val, return_counts= True))
# Out:
# (1382, 16, 16, 3) (432, 16, 16, 3) (346, 16, 16, 3)
# (1382,) (432,) (346,)
# (1382,) (432,) (346,)
# (array([0, 1, 2], dtype=int64), array([461, 461, 460], dtype=int64))
# (array([0, 1, 2], dtype=int64), array([144, 144, 144], dtype=int64))
# (array([0, 1, 2], dtype=int64), array([115, 115, 116], dtype=int64))

# %%
# One - hot encoding
trainTargets = to_categorical(y_train)
testTargets = to_categorical(y_test)
valTargets = to_categorical(y_val)

print("Train targets: ", trainTargets.shape)
print("Test targets: ", testTargets.shape)
print("Validation targets: ", valTargets.shape)
# Out:
# Train targets:  (1382, 3)
# Test targets:  (432, 3)
# Validation targets:  (346, 3)

# %%
weightPath = "./weights/"

# %%
# MobileNetV2 Transfer-learning
# Import convolution layer
# weight = None

with tf.device("/device:GPU:0"):
    inputTensor = Input(shape= (16, 16, 3))

    model = MobileNetV2(input_tensor= inputTensor,              # Input data shape
                        include_top= False,                     # Only convolution layer. If True: Use Classification layer
                        weights= None,                          # If weights= "imagenet" --> Use imagenet weights
                        pooling= 'max')

    x = model.output
    x = Dense(3, activation= 'softmax', kernel_initializer= 'he_normal')(x)

    model = Model(model.input, x)

    # Instantiate optimizer
    optim = optimizers.SGD(learning_rate= 0.01,
                           decay= 1e-3,
                           momentum= 0.9,
                           nesterov= True)

    # Compile model
    model.compile(optimizer= optim,
                  loss= 'categorical_crossentropy',
                  metrics= ['accuracy'])

    print("Training======================================")
    startTime = time.time()                                     # Training start time

    history = model.fit(X_train, trainTargets,
                        batch_size= 16,
                        epochs= 150,
                        verbose= 1,
                        validation_data= (X_val, valTargets)
                        )
    
    endTime = time.time()                                       # Training end time
    print(f"Training time: {np.round(endTime - startTime, 3)} sec")

    # save weight file
    model.save(os.path.join(weightPath, "GADF_MobileNetV2_3Class_16Sample.h5"))

    # Evaluate for total train dataset
    print("Score for train dataset")
    score = model.evaluate(X_train, trainTargets, verbose= 1)
    print(f"Score: \n{model.metrics_names[0]} : {score[0]}\n{model.metrics_names[0]} : {score[1] * 100} %")
# Out:
# Training======================================
# Epoch 1/150
# 87/87 [==============================] - 9s 39ms/step - loss: 0.9566 - accuracy: 0.6852 - val_loss: 1.1226 - val_accuracy: 0.3324
# Epoch 2/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.3818 - accuracy: 0.8944 - val_loss: 1.1305 - val_accuracy: 0.3324
# Epoch 3/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.1408 - accuracy: 0.9595 - val_loss: 1.1047 - val_accuracy: 0.3324
# Epoch 4/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0655 - accuracy: 0.9812 - val_loss: 1.1051 - val_accuracy: 0.3324
# Epoch 5/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.1041 - accuracy: 0.9667 - val_loss: 1.1008 - val_accuracy: 0.3324
# Epoch 6/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0910 - accuracy: 0.9805 - val_loss: 1.1035 - val_accuracy: 0.3324
# Epoch 7/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0756 - accuracy: 0.9848 - val_loss: 1.1031 - val_accuracy: 0.3324
# Epoch 8/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0490 - accuracy: 0.9913 - val_loss: 1.0998 - val_accuracy: 0.3324
# Epoch 9/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0253 - accuracy: 0.9949 - val_loss: 1.1126 - val_accuracy: 0.3324
# Epoch 10/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0437 - accuracy: 0.9877 - val_loss: 1.1329 - val_accuracy: 0.3324
# Epoch 11/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0254 - accuracy: 0.9913 - val_loss: 1.1181 - val_accuracy: 0.3324
# Epoch 12/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0947 - accuracy: 0.9863 - val_loss: 1.1125 - val_accuracy: 0.3324
# Epoch 13/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0739 - accuracy: 0.9834 - val_loss: 1.1123 - val_accuracy: 0.3324
# Epoch 14/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0267 - accuracy: 0.9942 - val_loss: 1.1134 - val_accuracy: 0.3353
# Epoch 15/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0313 - accuracy: 0.9942 - val_loss: 1.1033 - val_accuracy: 0.3324
# Epoch 16/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0153 - accuracy: 0.9971 - val_loss: 1.0995 - val_accuracy: 0.3324
# Epoch 17/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0536 - accuracy: 0.9913 - val_loss: 1.1083 - val_accuracy: 0.4364
# Epoch 18/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0134 - accuracy: 0.9971 - val_loss: 1.0919 - val_accuracy: 0.4104
# Epoch 19/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0124 - accuracy: 0.9971 - val_loss: 1.0879 - val_accuracy: 0.3353
# Epoch 20/150
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0351 - accuracy: 0.9920 - val_loss: 1.0993 - val_accuracy: 0.3324
# Epoch 21/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0394 - accuracy: 0.9935 - val_loss: 1.1475 - val_accuracy: 0.3324
# Epoch 22/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0254 - accuracy: 0.9971 - val_loss: 1.0942 - val_accuracy: 0.3324
# Epoch 23/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0067 - accuracy: 0.9993 - val_loss: 1.0772 - val_accuracy: 0.3324
# Epoch 24/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 1.0873 - val_accuracy: 0.3324
# Epoch 25/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0052 - accuracy: 0.9993 - val_loss: 1.1013 - val_accuracy: 0.3324
# Epoch 26/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0917 - val_accuracy: 0.3324
# Epoch 27/150
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0171 - accuracy: 0.9978 - val_loss: 1.1197 - val_accuracy: 0.3324
# Epoch 28/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0299 - accuracy: 0.9986 - val_loss: 1.0965 - val_accuracy: 0.3324
# Epoch 29/150
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 1.0856 - val_accuracy: 0.3324
# Epoch 30/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 1.0853 - val_accuracy: 0.3324
# Epoch 31/150
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 0.9964 - val_loss: 1.1662 - val_accuracy: 0.3324
# Epoch 32/150
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.1262 - val_accuracy: 0.3324
# Epoch 33/150
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.1098 - val_accuracy: 0.3324
# Epoch 34/150
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0119 - accuracy: 0.9993 - val_loss: 1.0932 - val_accuracy: 0.3324
# Epoch 35/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0692 - accuracy: 0.9884 - val_loss: 1.0355 - val_accuracy: 0.3324
# Epoch 36/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0092 - accuracy: 0.9993 - val_loss: 1.0179 - val_accuracy: 0.3324
# Epoch 37/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 1.0237 - val_accuracy: 0.3324
# Epoch 38/150
# 87/87 [==============================] - 2s 21ms/step - loss: 6.8277e-04 - accuracy: 1.0000 - val_loss: 1.0143 - val_accuracy: 0.3324
# Epoch 39/150
# 87/87 [==============================] - 2s 21ms/step - loss: 6.6514e-04 - accuracy: 1.0000 - val_loss: 0.9978 - val_accuracy: 0.3324
# Epoch 40/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0072 - accuracy: 0.9993 - val_loss: 0.9702 - val_accuracy: 0.3324
# Epoch 41/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0192 - accuracy: 0.9957 - val_loss: 0.9802 - val_accuracy: 0.3324
# Epoch 42/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.9467 - val_accuracy: 0.3324
# Epoch 43/150
# 87/87 [==============================] - 2s 20ms/step - loss: 0.0128 - accuracy: 0.9978 - val_loss: 0.9247 - val_accuracy: 0.3324
# Epoch 44/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.9400 - val_accuracy: 0.3324
# Epoch 45/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0273 - accuracy: 0.9942 - val_loss: 0.9101 - val_accuracy: 0.3613
# Epoch 46/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0137 - accuracy: 0.9964 - val_loss: 0.8886 - val_accuracy: 0.3613
# Epoch 47/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0340 - accuracy: 0.9957 - val_loss: 0.8711 - val_accuracy: 0.3613
# Epoch 48/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0091 - accuracy: 0.9993 - val_loss: 0.8741 - val_accuracy: 0.3613
# Epoch 49/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0059 - accuracy: 0.9986 - val_loss: 0.8936 - val_accuracy: 0.3613
# Epoch 50/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8101 - val_accuracy: 0.3613
# Epoch 51/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.7836 - val_accuracy: 0.3699
# Epoch 52/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0448 - accuracy: 0.9920 - val_loss: 0.7401 - val_accuracy: 0.3844
# Epoch 53/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.6187 - val_accuracy: 0.5145
# Epoch 54/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0088 - accuracy: 0.9986 - val_loss: 0.6378 - val_accuracy: 0.4566
# Epoch 55/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0281 - accuracy: 0.9957 - val_loss: 0.6349 - val_accuracy: 0.4364
# Epoch 56/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0324 - accuracy: 0.9957 - val_loss: 0.5742 - val_accuracy: 0.7572
# Epoch 57/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0177 - accuracy: 0.9978 - val_loss: 0.5099 - val_accuracy: 0.8092
# Epoch 58/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4673 - val_accuracy: 0.8410
# Epoch 59/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4134 - val_accuracy: 0.9220
# Epoch 60/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0087 - accuracy: 0.9986 - val_loss: 0.3626 - val_accuracy: 0.9566
# Epoch 61/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0173 - accuracy: 0.9978 - val_loss: 0.3659 - val_accuracy: 0.8873
# Epoch 62/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0120 - accuracy: 0.9986 - val_loss: 0.2989 - val_accuracy: 0.9566
# Epoch 63/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.2173 - val_accuracy: 0.9942
# Epoch 64/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.2096 - val_accuracy: 0.9971
# Epoch 65/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0167 - accuracy: 0.9978 - val_loss: 0.2693 - val_accuracy: 1.0000
# Epoch 66/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0200 - accuracy: 0.9964 - val_loss: 0.2216 - val_accuracy: 1.0000
# Epoch 67/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0078 - accuracy: 0.9986 - val_loss: 0.1960 - val_accuracy: 1.0000
# Epoch 68/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0133 - accuracy: 0.9993 - val_loss: 0.1511 - val_accuracy: 1.0000
# Epoch 69/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0486 - accuracy: 0.9906 - val_loss: 0.1886 - val_accuracy: 1.0000
# Epoch 70/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1962 - val_accuracy: 1.0000
# Epoch 71/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 1.0000
# Epoch 72/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 1.0000
# Epoch 73/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.1119 - val_accuracy: 1.0000
# Epoch 74/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0059 - accuracy: 0.9986 - val_loss: 0.1738 - val_accuracy: 1.0000
# Epoch 75/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1208 - val_accuracy: 1.0000
# Epoch 76/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0213 - accuracy: 0.9986 - val_loss: 0.0873 - val_accuracy: 1.0000
# Epoch 77/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0222 - accuracy: 0.9949 - val_loss: 0.1151 - val_accuracy: 1.0000
# Epoch 78/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0826 - val_accuracy: 1.0000
# Epoch 79/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0359 - accuracy: 0.9942 - val_loss: 0.1385 - val_accuracy: 1.0000
# Epoch 80/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0165 - accuracy: 0.9986 - val_loss: 0.1105 - val_accuracy: 1.0000
# Epoch 81/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 1.0000
# Epoch 82/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0079 - accuracy: 0.9993 - val_loss: 0.0650 - val_accuracy: 1.0000
# Epoch 83/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.0639 - val_accuracy: 1.0000
# Epoch 84/150
# 87/87 [==============================] - 2s 21ms/step - loss: 7.9511e-04 - accuracy: 1.0000 - val_loss: 0.0525 - val_accuracy: 1.0000
# Epoch 85/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0074 - accuracy: 0.9986 - val_loss: 0.0435 - val_accuracy: 1.0000
# Epoch 86/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 0.0355 - val_accuracy: 1.0000
# Epoch 87/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0301 - val_accuracy: 1.0000
# Epoch 88/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 1.0000
# Epoch 89/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0096 - accuracy: 0.9986 - val_loss: 0.0424 - val_accuracy: 1.0000
# Epoch 90/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0106 - accuracy: 0.9949 - val_loss: 0.0489 - val_accuracy: 1.0000
# Epoch 91/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.0278 - val_accuracy: 1.0000
# Epoch 92/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0113 - accuracy: 0.9986 - val_loss: 0.0523 - val_accuracy: 1.0000
# Epoch 93/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0077 - accuracy: 0.9986 - val_loss: 0.0359 - val_accuracy: 1.0000
# Epoch 94/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0093 - accuracy: 0.9971 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 95/150
# 87/87 [==============================] - 2s 22ms/step - loss: 7.8745e-04 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 1.0000
# Epoch 96/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0130 - accuracy: 0.9964 - val_loss: 0.0494 - val_accuracy: 1.0000
# Epoch 97/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.0438 - val_accuracy: 1.0000
# Epoch 98/150
# 87/87 [==============================] - 2s 21ms/step - loss: 9.9264e-04 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 99/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0107 - accuracy: 0.9986 - val_loss: 0.0296 - val_accuracy: 1.0000
# Epoch 100/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 101/150
# 87/87 [==============================] - 2s 22ms/step - loss: 9.2834e-04 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 102/150
# 87/87 [==============================] - 2s 22ms/step - loss: 8.0407e-04 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 103/150
# 87/87 [==============================] - 2s 22ms/step - loss: 5.8552e-04 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 104/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 105/150
# 87/87 [==============================] - 2s 22ms/step - loss: 7.9556e-04 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 106/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0126 - accuracy: 0.9986 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 107/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0129 - accuracy: 0.9978 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 108/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0173 - accuracy: 0.9964 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 109/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0087 - accuracy: 0.9986 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 110/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0069 - accuracy: 0.9986 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 111/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0088 - accuracy: 0.9986 - val_loss: 0.0568 - val_accuracy: 1.0000
# Epoch 112/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0268 - accuracy: 0.9957 - val_loss: 0.0632 - val_accuracy: 1.0000
# Epoch 113/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 114/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 115/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0133 - accuracy: 0.9978 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 116/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 117/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 118/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 119/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 120/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0075 - accuracy: 0.9993 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 121/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 122/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 123/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0089 - accuracy: 0.9986 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 124/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 125/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 126/150
# 87/87 [==============================] - 2s 22ms/step - loss: 9.2316e-04 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 127/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0204 - accuracy: 0.9957 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 128/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0042 - accuracy: 0.9993 - val_loss: 0.0617 - val_accuracy: 1.0000
# Epoch 129/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0491 - val_accuracy: 1.0000
# Epoch 130/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0539 - val_accuracy: 1.0000
# Epoch 131/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0196 - accuracy: 0.9978 - val_loss: 0.0411 - val_accuracy: 1.0000
# Epoch 132/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 0.0266 - val_accuracy: 1.0000
# Epoch 133/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0320 - accuracy: 0.9957 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 134/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 135/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0046 - accuracy: 0.9993 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 136/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 137/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 138/150
# 87/87 [==============================] - 2s 21ms/step - loss: 4.8161e-04 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 139/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0452 - accuracy: 0.9949 - val_loss: 0.0233 - val_accuracy: 1.0000
# Epoch 140/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0189 - accuracy: 0.9978 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 141/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0100 - accuracy: 0.9978 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 142/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 143/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0131 - accuracy: 0.9978 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 144/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0100 - accuracy: 0.9986 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 145/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 146/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 1.0000
# Epoch 147/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0424 - accuracy: 0.9935 - val_loss: 0.0314 - val_accuracy: 1.0000
# Epoch 148/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 1.0000
# Epoch 149/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 150/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 1.0000
# Training time: 286.881 sec
# Score for train dataset
# 44/44 [==============================] - 1s 7ms/step - loss: 0.0218 - accuracy: 1.0000
# Score:
# loss : 0.021837642416357994
# loss : 100.0 %

# %%
def plotHistory(history, train, validation):
    """
        plot training history
        Parameters
        ------------------------------
        history = history
        train = 'accuracy' or 'loss'
        validation = 'val_accuracy' or 'val_loss'
    """
    plt.figure(figsize= (8, 6))
    plt.plot(history.history[train])
    plt.plot(history.history[validation])
    plt.legend(['train', 'validation'], loc= 'center right')
    plt.xlabel("Epochs")
    if train == 'accuracy':
        plt.ylabel("Accuracy")
        plt.title(f"Accuracy for train dataset")
    elif train == "loss":
        plt.ylabel("Loss")
        plt.title("Loss for train dataset")
    plt.show()

# %%
plotHistory(history= history, train= 'accuracy', validation= 'val_accuracy')
plotHistory(history= history, train= 'loss', validation= 'val_loss')

# %%
# Evaluate test dataset
testScore = model.evaluate(X_test, testTargets, verbose= 1)
print(f"{model.metrics_names[0]} : {testScore[0]}\n{model.metrics_names[1]} : {testScore[1] * 100} %")
# Out:
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0197 - accuracy: 1.0000
# loss : 0.01966753415763378
# accuracy : 100.0 %

# %%
# Prediction for test dataset

prediction = model.predict(X_test)
predictionClass = np.argmax(prediction, axis= 1)        # One-hot encoding --> Original label

# Actual Class (One-hot encoding testTarget --> y_test)
if testTargets.ndim > 1:
    actualClass = np.argmax(testTargets, axis= 1)
else:
    actualClass = testTargets

# Classification report
print(f"Classification report: \n{classification_report(actualClass, predictionClass)}")

# Confusion matrix
plt.figure(figsize= (8, 6))
sns.heatmap(confusion_matrix(actualClass, predictionClass), 
            annot= True, 
            fmt= "d", 
            cmap= "Blues",
            cbar= False)
plt.title("Confusion matrix for test dataset")
plt.xlabel("Prediction class")
plt.ylabel("Actual class")
plt.show()
# Out:
# 14/14 [==============================] - 1s 7ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       144
#            1       1.00      1.00      1.00       144
#            2       1.00      1.00      1.00       144
#
#     accuracy                           1.00       432
#    macro avg       1.00      1.00      1.00       432
# weighted avg       1.00      1.00      1.00       432

# %%
# Prediction for 1 image

randomImgIdx = random.randrange(0, X_test.shape[0])

predictStartTime = time.time()

predictionImg = X_test[randomImgIdx]
predictionImg = np.expand_dims(predictionImg, axis= 0)

testPrediction = model.predict(predictionImg)

predictEndTime = time.time()

print("Random image index: ", randomImgIdx)
print("Random actual label: ", i_test[randomImgIdx])
print("Random actual class: ", actualClass[randomImgIdx])
print("Random prediction class: ", predictionClass[randomImgIdx])
# Out:
# 1/1 [==============================] - 0s 264ms/step
# Random image index:  385
# Random actual label:  L_649
# Random actual class:  1
# Random prediction class:  1
