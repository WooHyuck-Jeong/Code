# %%
import os
import glob
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import keras
import tensorflow as tf
from keras import optimizers
from keras.utils import to_categorical
from keras.layers import Dense, Input
from keras.models import Model, load_model
from keras.applications import MobileNetV2
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
dataPath = "../1_Data_Preprocessing/16Sample/3Class/GADF_3Class_16Sample.npz"
data = np.load(dataPath)

X_data = data['X_data']
y_data = data['y_data']
i_data = data['i_data']

data.close()

print("X_data: ", X_data.shape)
print("y_data: ", y_data.shape)
print("i_data: ", i_data.shape)
# Out:
# X_data:  (2160, 16, 16, 3)
# y_data:  (2160,)
# i_data:  (2160,)

# %%
# Data split

# Set random seed for reproductivity
seed = 42

# Train - Test split
X_train, X_test, y_train, y_test, i_train, i_test = train_test_split(X_data, y_data, i_data, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_data)

# Train - Validation split
X_train, X_val, y_train, y_val, i_train, i_val = train_test_split(X_train, y_train, i_train, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_train)

print(X_train.shape, X_test.shape, X_val.shape)
print(y_train.shape, y_test.shape, y_val.shape)
print(i_train.shape, i_test.shape, i_val.shape)

print(np.unique(y_train, return_counts= True))
print(np.unique(y_test, return_counts= True))
print(np.unique(y_val, return_counts= True))
# Out:
# (1382, 16, 16, 3) (432, 16, 16, 3) (346, 16, 16, 3)
# (1382,) (432,) (346,)
# (1382,) (432,) (346,)
# (array([0, 1, 2]), array([461, 461, 460], dtype=int64))
# (array([0, 1, 2]), array([144, 144, 144], dtype=int64))
# (array([0, 1, 2]), array([115, 115, 116], dtype=int64))

# %%
# One - hot encoding
trainTargets = to_categorical(y_train)
testTargets = to_categorical(y_test)
valTargets = to_categorical(y_val)

print("Train targets: ", trainTargets.shape)
print("Test targets: ", testTargets.shape)
print("Validation targets: ", valTargets.shape)
# Out:
# Train targets:  (1382, 3)
# Test targets:  (432, 3)
# Validation targets:  (346, 3)

# %%
weightPath = "./weights/"

# %%
# MobileNetV2 Transfer-learning
# Import convolution layer
# weight = None

with tf.device("/device:GPU:0"):
    inputTensor = Input(shape= (16, 16, 3))

    model = MobileNetV2(input_tensor= inputTensor,              # Input data shape
                        include_top= False,                     # Only convolution layer. If True: Use Classification layer
                        weights= None,                          # If weights= "imagenet" --> Use imagenet weights
                        pooling= 'max')

    x = model.output
    x = Dense(3, activation= 'softmax', kernel_initializer= 'he_normal')(x)

    model = Model(model.input, x)

    # Instantiate optimizer
    optim = optimizers.SGD(learning_rate= 0.01,
                           decay= 1e-3,
                           momentum= 0.9,
                           nesterov= True)

    # Compile model
    model.compile(optimizer= optim,
                  loss= 'categorical_crossentropy',
                  metrics= ['accuracy'])

    print("Training======================================")
    startTime = time.time()                                     # Training start time

    history = model.fit(X_train, trainTargets,
                        batch_size= 16,
                        epochs= 150,
                        verbose= 1,
                        validation_data= (X_val, valTargets)
                        )
    
    endTime = time.time()                                       # Training end time
    print(f"Training time: {np.round(endTime - startTime, 3)} sec")

    # save weight file
    model.save(os.path.join(weightPath, "GADF_MobileNetV2_3Class_16Sample.h5"))

    # Evaluate for total train dataset
    print("Score for train dataset")
    score = model.evaluate(X_train, trainTargets, verbose= 1)
    print(f"Score: \n{model.metrics_names[0]} : {score[0]}\n{model.metrics_names[0]} : {score[1] * 100} %")
# Out:
# Training======================================
# Epoch 1/150
# 87/87 [==============================] - 9s 42ms/step - loss: 0.9298 - accuracy: 0.6700 - val_loss: 1.1129 - val_accuracy: 0.3324
# Epoch 2/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.3491 - accuracy: 0.8922 - val_loss: 1.1007 - val_accuracy: 0.3324
# Epoch 3/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.2630 - accuracy: 0.9255 - val_loss: 1.1024 - val_accuracy: 0.3324
# Epoch 4/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.1565 - accuracy: 0.9588 - val_loss: 1.1160 - val_accuracy: 0.3324
# Epoch 5/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.1245 - accuracy: 0.9653 - val_loss: 1.1389 - val_accuracy: 0.3324
# Epoch 6/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.1164 - accuracy: 0.9674 - val_loss: 1.1099 - val_accuracy: 0.3324
# Epoch 7/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0856 - accuracy: 0.9812 - val_loss: 1.1464 - val_accuracy: 0.3324
# Epoch 8/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0549 - accuracy: 0.9841 - val_loss: 1.1316 - val_accuracy: 0.3324
# Epoch 9/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0217 - accuracy: 0.9906 - val_loss: 1.1431 - val_accuracy: 0.3324
# Epoch 10/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0673 - accuracy: 0.9834 - val_loss: 1.1584 - val_accuracy: 0.3324
# Epoch 11/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0683 - accuracy: 0.9841 - val_loss: 1.1270 - val_accuracy: 0.3324
# Epoch 12/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0539 - accuracy: 0.9841 - val_loss: 1.1780 - val_accuracy: 0.3324
# Epoch 13/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0293 - accuracy: 0.9935 - val_loss: 1.1201 - val_accuracy: 0.3324
# Epoch 14/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0107 - accuracy: 0.9978 - val_loss: 1.1461 - val_accuracy: 0.3324
# Epoch 15/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 1.1754 - val_accuracy: 0.3324
# Epoch 16/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0112 - accuracy: 0.9971 - val_loss: 1.2120 - val_accuracy: 0.3324
# Epoch 17/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0520 - accuracy: 0.9928 - val_loss: 1.2046 - val_accuracy: 0.3324
# Epoch 18/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 1.2168 - val_accuracy: 0.3324
# Epoch 19/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0346 - accuracy: 0.9949 - val_loss: 1.2868 - val_accuracy: 0.3324
# Epoch 20/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0535 - accuracy: 0.9942 - val_loss: 1.2583 - val_accuracy: 0.3324
# Epoch 21/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0187 - accuracy: 0.9964 - val_loss: 1.2595 - val_accuracy: 0.3324
# Epoch 22/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0232 - accuracy: 0.9957 - val_loss: 1.2555 - val_accuracy: 0.3324
# Epoch 23/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0147 - accuracy: 0.9964 - val_loss: 1.2787 - val_accuracy: 0.3324
# Epoch 24/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0195 - accuracy: 0.9986 - val_loss: 1.2761 - val_accuracy: 0.3324
# Epoch 25/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0191 - accuracy: 0.9978 - val_loss: 1.4277 - val_accuracy: 0.3324
# Epoch 26/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0283 - accuracy: 0.9957 - val_loss: 1.4770 - val_accuracy: 0.3324
# Epoch 27/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.3853 - val_accuracy: 0.3324
# Epoch 28/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 1.3395 - val_accuracy: 0.3324
# Epoch 29/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0889 - accuracy: 0.9877 - val_loss: 1.2096 - val_accuracy: 0.3324
# Epoch 30/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.2371 - val_accuracy: 0.3324
# Epoch 31/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0217 - accuracy: 0.9971 - val_loss: 1.2545 - val_accuracy: 0.3324
# Epoch 32/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0408 - accuracy: 0.9913 - val_loss: 1.1678 - val_accuracy: 0.3324
# Epoch 33/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 1.1509 - val_accuracy: 0.3324
# Epoch 34/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 1.1913 - val_accuracy: 0.3324
# Epoch 35/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 1.1532 - val_accuracy: 0.3324
# Epoch 36/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0206 - accuracy: 0.9978 - val_loss: 1.1461 - val_accuracy: 0.3324
# Epoch 37/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.1684 - val_accuracy: 0.3324
# Epoch 38/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0367 - accuracy: 0.9949 - val_loss: 1.0161 - val_accuracy: 0.3324
# Epoch 39/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0097 - accuracy: 0.9986 - val_loss: 1.1147 - val_accuracy: 0.3324
# Epoch 40/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0217 - accuracy: 0.9964 - val_loss: 1.1300 - val_accuracy: 0.3324
# Epoch 41/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.1342 - val_accuracy: 0.3324
# Epoch 42/150
# 87/87 [==============================] - 2s 23ms/step - loss: 8.7753e-04 - accuracy: 1.0000 - val_loss: 1.1249 - val_accuracy: 0.3324
# Epoch 43/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0177 - accuracy: 0.9978 - val_loss: 1.1458 - val_accuracy: 0.3324
# Epoch 44/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 1.1698 - val_accuracy: 0.3324
# Epoch 45/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0050 - accuracy: 0.9993 - val_loss: 1.2199 - val_accuracy: 0.3324
# Epoch 46/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 1.1601 - val_accuracy: 0.3324
# Epoch 47/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0255 - accuracy: 0.9957 - val_loss: 1.1587 - val_accuracy: 0.3324
# Epoch 48/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0252 - accuracy: 0.9971 - val_loss: 1.1184 - val_accuracy: 0.3324
# Epoch 49/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0060 - accuracy: 0.9986 - val_loss: 0.9843 - val_accuracy: 0.3324
# Epoch 50/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.9384 - val_accuracy: 0.3324
# Epoch 51/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0130 - accuracy: 0.9986 - val_loss: 0.8916 - val_accuracy: 0.3324
# Epoch 52/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0416 - accuracy: 0.9928 - val_loss: 0.7519 - val_accuracy: 0.5260
# Epoch 53/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0059 - accuracy: 0.9986 - val_loss: 0.7699 - val_accuracy: 0.3873
# Epoch 54/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.7462 - val_accuracy: 0.4451
# Epoch 55/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0261 - accuracy: 0.9949 - val_loss: 0.9162 - val_accuracy: 0.3324
# Epoch 56/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0170 - accuracy: 0.9986 - val_loss: 0.8727 - val_accuracy: 0.3324
# Epoch 57/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.7644 - val_accuracy: 0.4740
# Epoch 58/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0240 - accuracy: 0.9964 - val_loss: 0.7479 - val_accuracy: 0.4855
# Epoch 59/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.6770 - val_accuracy: 0.5954
# Epoch 60/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0121 - accuracy: 0.9986 - val_loss: 0.6234 - val_accuracy: 0.7197
# Epoch 61/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.5752 - val_accuracy: 0.8555
# Epoch 62/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0494 - accuracy: 0.9913 - val_loss: 0.5333 - val_accuracy: 0.8786
# Epoch 63/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0160 - accuracy: 0.9971 - val_loss: 0.4904 - val_accuracy: 0.8728
# Epoch 64/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4369 - val_accuracy: 0.9162
# Epoch 65/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0206 - accuracy: 0.9978 - val_loss: 0.3796 - val_accuracy: 0.9740
# Epoch 66/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0358 - accuracy: 0.9935 - val_loss: 0.4179 - val_accuracy: 0.8815
# Epoch 67/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3456 - val_accuracy: 0.9624
# Epoch 68/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0054 - accuracy: 0.9993 - val_loss: 0.3231 - val_accuracy: 0.9682
# Epoch 69/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0058 - accuracy: 0.9993 - val_loss: 0.3318 - val_accuracy: 0.8988
# Epoch 70/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0341 - accuracy: 0.9935 - val_loss: 0.2939 - val_accuracy: 0.9364
# Epoch 71/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0162 - accuracy: 0.9971 - val_loss: 0.3137 - val_accuracy: 0.9364
# Epoch 72/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0060 - accuracy: 0.9986 - val_loss: 0.2722 - val_accuracy: 0.9769
# Epoch 73/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0152 - accuracy: 0.9971 - val_loss: 0.2092 - val_accuracy: 0.9855
# Epoch 74/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0186 - accuracy: 0.9978 - val_loss: 0.1636 - val_accuracy: 1.0000
# Epoch 75/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1312 - val_accuracy: 1.0000
# Epoch 76/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1056 - val_accuracy: 1.0000
# Epoch 77/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1075 - val_accuracy: 0.9971
# Epoch 78/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0263 - accuracy: 0.9942 - val_loss: 0.1130 - val_accuracy: 1.0000
# Epoch 79/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0431 - accuracy: 0.9935 - val_loss: 0.1324 - val_accuracy: 1.0000
# Epoch 80/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0834 - val_accuracy: 0.9971
# Epoch 81/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 1.0000
# Epoch 82/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0073 - accuracy: 0.9986 - val_loss: 0.0781 - val_accuracy: 1.0000
# Epoch 83/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0253 - accuracy: 0.9957 - val_loss: 0.0671 - val_accuracy: 1.0000
# Epoch 84/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0044 - accuracy: 0.9993 - val_loss: 0.0537 - val_accuracy: 1.0000
# Epoch 85/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0485 - val_accuracy: 1.0000
# Epoch 86/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 1.0000
# Epoch 87/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0090 - accuracy: 0.9993 - val_loss: 0.0396 - val_accuracy: 1.0000
# Epoch 88/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0146 - accuracy: 0.9971 - val_loss: 0.0401 - val_accuracy: 1.0000
# Epoch 89/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0049 - accuracy: 0.9993 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 90/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 0.0335 - val_accuracy: 1.0000
# Epoch 91/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0211 - accuracy: 0.9949 - val_loss: 0.0388 - val_accuracy: 1.0000
# Epoch 92/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 1.0000
# Epoch 93/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 1.0000
# Epoch 94/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0252 - val_accuracy: 1.0000
# Epoch 95/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 96/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 97/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0097 - accuracy: 0.9986 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 98/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0313 - accuracy: 0.9949 - val_loss: 0.1621 - val_accuracy: 0.9133
# Epoch 99/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0844 - val_accuracy: 0.9855
# Epoch 100/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9971
# Epoch 101/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0491 - val_accuracy: 1.0000
# Epoch 102/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0201 - accuracy: 0.9978 - val_loss: 0.0420 - val_accuracy: 1.0000
# Epoch 103/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0352 - val_accuracy: 1.0000
# Epoch 104/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 105/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.0278 - val_accuracy: 1.0000
# Epoch 106/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.0260 - val_accuracy: 1.0000
# Epoch 107/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 108/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0049 - accuracy: 0.9993 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 109/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0214 - accuracy: 0.9964 - val_loss: 0.0837 - val_accuracy: 0.9682
# Epoch 110/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0103 - accuracy: 0.9986 - val_loss: 0.0689 - val_accuracy: 0.9769
# Epoch 111/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0502 - val_accuracy: 0.9884
# Epoch 112/150
# 87/87 [==============================] - 2s 22ms/step - loss: 8.0878e-04 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9913
# Epoch 113/150
# 87/87 [==============================] - 2s 22ms/step - loss: 8.3216e-04 - accuracy: 1.0000 - val_loss: 0.0357 - val_accuracy: 0.9913
# Epoch 114/150
# 87/87 [==============================] - 2s 22ms/step - loss: 7.0408e-04 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 0.9942
# Epoch 115/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0124 - accuracy: 0.9978 - val_loss: 0.0246 - val_accuracy: 1.0000
# Epoch 116/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 117/150
# 87/87 [==============================] - 2s 24ms/step - loss: 7.3374e-04 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 118/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0176 - accuracy: 0.9964 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 119/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0046 - accuracy: 0.9993 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 120/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0325 - accuracy: 0.9920 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 121/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0116 - accuracy: 0.9986 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 122/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.0207 - val_accuracy: 1.0000
# Epoch 123/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 124/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 125/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 126/150
# 87/87 [==============================] - 2s 24ms/step - loss: 9.6791e-04 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 127/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 128/150
# 87/87 [==============================] - 2s 23ms/step - loss: 8.4278e-04 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 129/150
# 87/87 [==============================] - 2s 24ms/step - loss: 7.0260e-04 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 130/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0142 - accuracy: 0.9964 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 131/150
# 87/87 [==============================] - 2s 24ms/step - loss: 9.7617e-04 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 132/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 133/150
# 87/87 [==============================] - 2s 24ms/step - loss: 4.8377e-04 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 134/150
# 87/87 [==============================] - 2s 25ms/step - loss: 8.7959e-04 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 135/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0133 - accuracy: 0.9986 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 136/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0122 - accuracy: 0.9964 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 137/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 138/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0055 - accuracy: 0.9993 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 139/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 140/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0179 - accuracy: 0.9978 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 141/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 142/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 143/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 144/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0052 - accuracy: 0.9993 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 145/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 146/150
# 87/87 [==============================] - 2s 24ms/step - loss: 9.5320e-04 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 147/150
# 87/87 [==============================] - 2s 25ms/step - loss: 7.9597e-04 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 1.0000
# Epoch 148/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 149/150
# 87/87 [==============================] - 2s 25ms/step - loss: 9.9534e-04 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 150/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 1.0000
# Training time: 319.067 sec
# Score for train dataset
# 44/44 [==============================] - 1s 8ms/step - loss: 0.0134 - accuracy: 1.0000
# Score:
# loss : 0.013442394323647022
# loss : 100.0 %

# %%
def plotHistory(history, train, validation):
    """
        plot training history
        Parameters
        ------------------------------
        history = history
        train = 'accuracy' or 'loss'
        validation = 'val_accuracy' or 'val_loss'
    """
    plt.figure(figsize= (8, 6))
    plt.plot(history.history[train])
    plt.plot(history.history[validation])
    plt.legend(['train', 'validation'], loc= 'center right')
    plt.xlabel("Epochs")
    if train == 'accuracy':
        plt.ylabel("Accuracy")
        plt.title(f"Accuracy for train dataset")
    elif train == "loss":
        plt.ylabel("Loss")
        plt.title("Loss for train dataset")
    plt.show()

# %%
plotHistory(history= history, train= 'accuracy', validation= 'val_accuracy')
plotHistory(history= history, train= 'loss', validation= 'val_loss')

# %%
# Evaluate test dataset
testScore = model.evaluate(X_test, testTargets, verbose= 1)
print(f"{model.metrics_names[0]} : {testScore[0]}\n{model.metrics_names[1]} : {testScore[1] * 100} %")
# Out:
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0150 - accuracy: 1.0000
# loss : 0.015027500689029694
# accuracy : 100.0 %

# %%
# Prediction for test dataset

prediction = model.predict(X_test)
predictionClass = np.argmax(prediction, axis= 1)        # One-hot encoding --> Original label

# Actual Class (One-hot encoding testTarget --> y_test)
if testTargets.ndim > 1:
    actualClass = np.argmax(testTargets, axis= 1)
else:
    actualClass = testTargets

# Classification report
print(f"Classification report: \n{classification_report(actualClass, predictionClass)}")

# Confusion matrix
plt.figure(figsize= (8, 6))
sns.heatmap(confusion_matrix(actualClass, predictionClass), 
            annot= True, 
            fmt= "d", 
            cmap= "Blues",
            cbar= False)
plt.title("Confusion matrix for test dataset")
plt.xlabel("Prediction class")
plt.ylabel("Actual class")
plt.show()
# Out:
# 14/14 [==============================] - 1s 7ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       144
#            1       1.00      1.00      1.00       144
#            2       1.00      1.00      1.00       144
#
#     accuracy                           1.00       432
#    macro avg       1.00      1.00      1.00       432
# weighted avg       1.00      1.00      1.00       432

# %%
# Prediction for 1 image

randomImgIdx = random.randrange(0, X_test.shape[0])

predictStartTime = time.time()

predictionImg = X_test[randomImgIdx]
predictionImg = np.expand_dims(predictionImg, axis= 0)

testPrediction = model.predict(predictionImg)

predictEndTime = time.time()

print("Random image index: ", randomImgIdx)
print("Random actual label: ", i_test[randomImgIdx])
print("Random actual class: ", actualClass[randomImgIdx])
print("Random prediction class: ", predictionClass[randomImgIdx])
# Out:
# 1/1 [==============================] - 0s 244ms/step
# Random image index:  156
# Random actual label:  L_27
# Random actual class:  1
# Random prediction class:  1
