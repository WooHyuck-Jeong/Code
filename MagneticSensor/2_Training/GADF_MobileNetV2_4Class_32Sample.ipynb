# %%
import os
import glob
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import keras
import tensorflow as tf
from keras import optimizers
from keras.utils import to_categorical
from keras.layers import Dense, Input
from keras.models import Model, load_model
from keras.applications import MobileNetV2
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
dataPath = "../1_Data_Preprocessing/32Sample/4Class/GADF_4Class_32Sample.npz"
data = np.load(dataPath)

X_data = data['X_data']
y_data = data['y_data']
i_data = data['i_data']

data.close()

print("X_data: ", X_data.shape)
print("y_data: ", y_data.shape)
print("i_data: ", i_data.shape)
# Out:
# X_data:  (1440, 32, 32, 3)
# y_data:  (1440,)
# i_data:  (1440,)

# %%
# Data split

# Set random seed for reproductivity
seed = 42

# Train - Test split
X_train, X_test, y_train, y_test, i_train, i_test = train_test_split(X_data, y_data, i_data, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_data)

# Train - Validation split
X_train, X_val, y_train, y_val, i_train, i_val = train_test_split(X_train, y_train, i_train, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_train)

print(X_train.shape, X_test.shape, X_val.shape)
print(y_train.shape, y_test.shape, y_val.shape)
print(i_train.shape, i_test.shape, i_val.shape)

print(np.unique(y_train, return_counts= True))
print(np.unique(y_test, return_counts= True))
print(np.unique(y_val, return_counts= True))
# Out:
# (921, 32, 32, 3) (288, 32, 32, 3) (231, 32, 32, 3)
# (921,) (288,) (231,)
# (921,) (288,) (231,)
# (array([0, 1, 2, 3], dtype=int64), array([230, 231, 230, 230], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([72, 72, 72, 72], dtype=int64))
# (array([0, 1, 2, 3], dtype=int64), array([58, 57, 58, 58], dtype=int64))

# %%
# One - hot encoding
trainTargets = to_categorical(y_train)
testTargets = to_categorical(y_test)
valTargets = to_categorical(y_val)

print("Train targets: ", trainTargets.shape)
print("Test targets: ", testTargets.shape)
print("Validation targets: ", valTargets.shape)
# Out:
# Train targets:  (921, 4)
# Test targets:  (288, 4)
# Validation targets:  (231, 4)

# %%
weightPath = "./weights/"

# %%
# MobileNetV2 Transfer-learning
# Import convolution layer
# weight = None

with tf.device("/device:GPU:0"):
    inputTensor = Input(shape= (32, 32, 3))

    model = MobileNetV2(input_tensor= inputTensor,              # Input data shape
                        include_top= False,                     # Only convolution layer. If True: Use Classification layer
                        weights= None,                          # If weights= "imagenet" --> Use imagenet weights
                        pooling= 'max')

    x = model.output
    x = Dense(4, activation= 'softmax', kernel_initializer= 'he_normal')(x)

    model = Model(model.input, x)

    # Instantiate optimizer
    optim = optimizers.SGD(learning_rate= 0.01,
                           decay= 1e-3,
                           momentum= 0.9,
                           nesterov= True)

    # Compile model
    model.compile(optimizer= optim,
                  loss= 'categorical_crossentropy',
                  metrics= ['accuracy'])

    print("Training======================================")
    startTime = time.time()                                     # Training start time

    history = model.fit(X_train, trainTargets,
                        batch_size= 16,
                        epochs= 150,
                        verbose= 1,
                        validation_data= (X_val, valTargets)
                        )
    
    endTime = time.time()                                       # Training end time
    print(f"Training time: {np.round(endTime - startTime, 3)} sec")

    # save weight file
    model.save(os.path.join(weightPath, "GADF_MobileNetV2_4Class_32Sample.h5"))

    # Evaluate for total train dataset
    print("Score for train dataset")
    score = model.evaluate(X_train, trainTargets, verbose= 1)
    print(f"Score: \n{model.metrics_names[0]} : {score[0]}\n{model.metrics_names[0]} : {score[1] * 100} %")
# Out:
# Training======================================
# Epoch 1/200
# 58/58 [==============================] - 9s 50ms/step - loss: 0.8054 - accuracy: 0.7568 - val_loss: 1.4490 - val_accuracy: 0.2468
# Epoch 2/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.3866 - accuracy: 0.8773 - val_loss: 1.4913 - val_accuracy: 0.2468
# Epoch 3/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0798 - accuracy: 0.9750 - val_loss: 1.4241 - val_accuracy: 0.2468
# Epoch 4/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.1918 - accuracy: 0.9598 - val_loss: 1.4078 - val_accuracy: 0.2468
# Epoch 5/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.1501 - accuracy: 0.9837 - val_loss: 1.3980 - val_accuracy: 0.2468
# Epoch 6/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0989 - accuracy: 0.9739 - val_loss: 1.4068 - val_accuracy: 0.2511
# Epoch 7/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.1754 - accuracy: 0.9674 - val_loss: 1.3977 - val_accuracy: 0.2511
# Epoch 8/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0796 - accuracy: 0.9902 - val_loss: 1.4081 - val_accuracy: 0.2511
# Epoch 9/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0660 - accuracy: 0.9881 - val_loss: 1.3970 - val_accuracy: 0.2511
# Epoch 10/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0505 - accuracy: 0.9902 - val_loss: 1.4114 - val_accuracy: 0.2511
# Epoch 11/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0757 - accuracy: 0.9848 - val_loss: 1.4184 - val_accuracy: 0.2511
# Epoch 12/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0190 - accuracy: 0.9989 - val_loss: 1.4166 - val_accuracy: 0.2511
# Epoch 13/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0409 - accuracy: 0.9935 - val_loss: 1.4167 - val_accuracy: 0.2511
# Epoch 14/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.1064 - accuracy: 0.9826 - val_loss: 1.4001 - val_accuracy: 0.2511
# Epoch 15/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0413 - accuracy: 0.9913 - val_loss: 1.4367 - val_accuracy: 0.2511
# Epoch 16/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0404 - accuracy: 0.9902 - val_loss: 1.4235 - val_accuracy: 0.2511
# Epoch 17/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0985 - accuracy: 0.9837 - val_loss: 1.4537 - val_accuracy: 0.2511
# Epoch 18/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0259 - accuracy: 0.9957 - val_loss: 1.4327 - val_accuracy: 0.2511
# Epoch 19/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0525 - accuracy: 0.9913 - val_loss: 1.4153 - val_accuracy: 0.2511
# Epoch 20/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0827 - accuracy: 0.9891 - val_loss: 1.4143 - val_accuracy: 0.2511
# Epoch 21/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0504 - accuracy: 0.9924 - val_loss: 1.4187 - val_accuracy: 0.2511
# Epoch 22/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0178 - accuracy: 0.9978 - val_loss: 1.3937 - val_accuracy: 0.2511
# Epoch 23/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0873 - accuracy: 0.9783 - val_loss: 1.4437 - val_accuracy: 0.2511
# Epoch 24/200
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0441 - accuracy: 0.9924 - val_loss: 1.4034 - val_accuracy: 0.2511
# Epoch 25/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0318 - accuracy: 0.9946 - val_loss: 1.4260 - val_accuracy: 0.2511
# Epoch 26/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0472 - accuracy: 0.9957 - val_loss: 1.4301 - val_accuracy: 0.2511
# Epoch 27/200
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 1.4204 - val_accuracy: 0.2511
# Epoch 28/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0393 - accuracy: 0.9935 - val_loss: 1.4208 - val_accuracy: 0.2511
# Epoch 29/200
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0512 - accuracy: 0.9859 - val_loss: 1.3796 - val_accuracy: 0.2511
# Epoch 30/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0143 - accuracy: 0.9957 - val_loss: 1.5321 - val_accuracy: 0.2511
# Epoch 31/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0067 - accuracy: 0.9989 - val_loss: 1.4716 - val_accuracy: 0.2511
# Epoch 32/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 1.4351 - val_accuracy: 0.2511
# Epoch 33/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0314 - accuracy: 0.9967 - val_loss: 1.4173 - val_accuracy: 0.2511
# Epoch 34/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0495 - accuracy: 0.9870 - val_loss: 1.3937 - val_accuracy: 0.2511
# Epoch 35/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0393 - accuracy: 0.9957 - val_loss: 1.3706 - val_accuracy: 0.2511
# Epoch 36/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.3649 - val_accuracy: 0.2511
# Epoch 37/200
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0330 - accuracy: 0.9957 - val_loss: 1.3491 - val_accuracy: 0.2511
# Epoch 38/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.3309 - val_accuracy: 0.2511
# Epoch 39/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0108 - accuracy: 0.9989 - val_loss: 1.3296 - val_accuracy: 0.2511
# Epoch 40/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.3020 - val_accuracy: 0.2511
# Epoch 41/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0156 - accuracy: 0.9989 - val_loss: 1.2843 - val_accuracy: 0.2511
# Epoch 42/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0438 - accuracy: 0.9946 - val_loss: 1.2661 - val_accuracy: 0.2511
# Epoch 43/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 1.2576 - val_accuracy: 0.2511
# Epoch 44/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0159 - accuracy: 0.9978 - val_loss: 1.2358 - val_accuracy: 0.2511
# Epoch 45/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0867 - accuracy: 0.9826 - val_loss: 1.2105 - val_accuracy: 0.3506
# Epoch 46/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0327 - accuracy: 0.9957 - val_loss: 1.2155 - val_accuracy: 0.2511
# Epoch 47/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.1843 - val_accuracy: 0.3290
# Epoch 48/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0324 - accuracy: 0.9957 - val_loss: 1.1643 - val_accuracy: 0.3290
# Epoch 49/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0146 - accuracy: 0.9946 - val_loss: 1.1005 - val_accuracy: 0.4935
# Epoch 50/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0344 - accuracy: 0.9946 - val_loss: 1.0973 - val_accuracy: 0.3723
# Epoch 51/200
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0698 - val_accuracy: 0.4113
# Epoch 52/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.0113 - val_accuracy: 0.4762
# Epoch 53/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0152 - accuracy: 0.9978 - val_loss: 1.0058 - val_accuracy: 0.4502
# Epoch 54/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0210 - accuracy: 0.9967 - val_loss: 0.9990 - val_accuracy: 0.4632
# Epoch 55/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.9936 - val_accuracy: 0.4459
# Epoch 56/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0322 - accuracy: 0.9946 - val_loss: 0.9559 - val_accuracy: 0.4935
# Epoch 57/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.9196 - val_accuracy: 0.4935
# Epoch 58/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0147 - accuracy: 0.9989 - val_loss: 0.8848 - val_accuracy: 0.5022
# Epoch 59/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.8502 - val_accuracy: 0.5238
# Epoch 60/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0268 - accuracy: 0.9967 - val_loss: 0.8332 - val_accuracy: 0.5671
# Epoch 61/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0212 - accuracy: 0.9967 - val_loss: 0.7343 - val_accuracy: 0.7403
# Epoch 62/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0183 - accuracy: 0.9967 - val_loss: 0.6972 - val_accuracy: 0.7749
# Epoch 63/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0203 - accuracy: 0.9978 - val_loss: 0.6675 - val_accuracy: 0.8139
# Epoch 64/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0275 - accuracy: 0.9967 - val_loss: 0.6528 - val_accuracy: 0.7706
# Epoch 65/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0075 - accuracy: 0.9989 - val_loss: 0.6764 - val_accuracy: 0.5801
# Epoch 66/200
# 58/58 [==============================] - 1s 23ms/step - loss: 9.6339e-04 - accuracy: 1.0000 - val_loss: 0.6233 - val_accuracy: 0.6277
# Epoch 67/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.5631 - val_accuracy: 0.7100
# Epoch 68/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0209 - accuracy: 0.9946 - val_loss: 0.5370 - val_accuracy: 0.7532
# Epoch 69/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.5560 - val_accuracy: 0.6104
# Epoch 70/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0302 - accuracy: 0.9967 - val_loss: 0.5674 - val_accuracy: 0.6753
# Epoch 71/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0389 - accuracy: 0.9913 - val_loss: 0.5294 - val_accuracy: 0.8442
# Epoch 72/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.5045 - val_accuracy: 0.8788
# Epoch 73/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0231 - accuracy: 0.9978 - val_loss: 0.4569 - val_accuracy: 0.9437
# Epoch 74/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.3978 - val_accuracy: 0.9654
# Epoch 75/200
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0109 - accuracy: 0.9989 - val_loss: 0.3502 - val_accuracy: 0.9784
# Epoch 76/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.3491 - val_accuracy: 0.9481
# Epoch 77/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0196 - accuracy: 0.9957 - val_loss: 0.2925 - val_accuracy: 0.9957
# Epoch 78/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.2270 - val_accuracy: 1.0000
# Epoch 79/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0176 - accuracy: 0.9978 - val_loss: 0.2159 - val_accuracy: 1.0000
# Epoch 80/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0117 - accuracy: 0.9978 - val_loss: 0.1855 - val_accuracy: 1.0000
# Epoch 81/200
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0088 - accuracy: 0.9989 - val_loss: 0.1631 - val_accuracy: 1.0000
# Epoch 82/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0081 - accuracy: 0.9989 - val_loss: 0.1449 - val_accuracy: 1.0000
# Epoch 83/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 1.0000
# Epoch 84/200
# 58/58 [==============================] - 1s 23ms/step - loss: 8.0980e-04 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 1.0000
# Epoch 85/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0199 - accuracy: 0.9967 - val_loss: 0.0915 - val_accuracy: 1.0000
# Epoch 86/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0283 - accuracy: 0.9946 - val_loss: 0.0845 - val_accuracy: 1.0000
# Epoch 87/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0083 - accuracy: 0.9989 - val_loss: 0.0690 - val_accuracy: 1.0000
# Epoch 88/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0084 - accuracy: 0.9989 - val_loss: 0.0613 - val_accuracy: 1.0000
# Epoch 89/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0559 - val_accuracy: 1.0000
# Epoch 90/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0249 - accuracy: 0.9967 - val_loss: 0.0531 - val_accuracy: 1.0000
# Epoch 91/200
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0098 - accuracy: 0.9989 - val_loss: 0.0461 - val_accuracy: 1.0000
# Epoch 92/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0066 - accuracy: 0.9989 - val_loss: 0.0390 - val_accuracy: 1.0000
# Epoch 93/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0091 - accuracy: 0.9989 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 94/200
# 58/58 [==============================] - 1s 24ms/step - loss: 5.0309e-04 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 1.0000
# Epoch 95/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0185 - accuracy: 0.9967 - val_loss: 0.0252 - val_accuracy: 1.0000
# Epoch 96/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 97/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0093 - accuracy: 0.9978 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 98/200
# 58/58 [==============================] - 1s 23ms/step - loss: 5.5786e-04 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 99/200
# 58/58 [==============================] - 1s 24ms/step - loss: 4.8913e-04 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 100/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 101/200
# 58/58 [==============================] - 1s 25ms/step - loss: 2.4783e-04 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 102/200
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 103/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0077 - accuracy: 0.9989 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 104/200
# 58/58 [==============================] - 1s 23ms/step - loss: 5.0191e-04 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 105/200
# 58/58 [==============================] - 1s 23ms/step - loss: 2.6983e-04 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 106/200
# 58/58 [==============================] - 1s 23ms/step - loss: 4.6076e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 107/200
# 58/58 [==============================] - 1s 23ms/step - loss: 3.0087e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 108/200
# 58/58 [==============================] - 1s 23ms/step - loss: 3.2324e-04 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 109/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0310 - accuracy: 0.9913 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 110/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0178 - accuracy: 0.9978 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 111/200
# 58/58 [==============================] - 1s 23ms/step - loss: 8.9665e-04 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 112/200
# 58/58 [==============================] - 1s 24ms/step - loss: 6.0472e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 113/200
# 58/58 [==============================] - 1s 24ms/step - loss: 8.9326e-04 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 114/200
# 58/58 [==============================] - 1s 23ms/step - loss: 4.0023e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 115/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0138 - accuracy: 0.9967 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 116/200
# 58/58 [==============================] - 1s 24ms/step - loss: 6.0927e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 117/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0069 - accuracy: 0.9989 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 118/200
# 58/58 [==============================] - 1s 23ms/step - loss: 4.5935e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 119/200
# 58/58 [==============================] - 1s 24ms/step - loss: 6.7522e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 120/200
# 58/58 [==============================] - 1s 23ms/step - loss: 2.0722e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 121/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0187 - accuracy: 0.9967 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 122/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0091 - accuracy: 0.9989 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 123/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 124/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 125/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0176 - accuracy: 0.9946 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 126/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0094 - accuracy: 0.9978 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 127/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 9.2466e-04 - val_accuracy: 1.0000
# Epoch 128/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0146 - accuracy: 0.9978 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 129/200
# 58/58 [==============================] - 1s 24ms/step - loss: 4.1831e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 130/200
# 58/58 [==============================] - 1s 22ms/step - loss: 3.3951e-04 - accuracy: 1.0000 - val_loss: 9.1223e-04 - val_accuracy: 1.0000
# Epoch 131/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 132/200
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 6.8745e-04 - val_accuracy: 1.0000
# Epoch 133/200
# 58/58 [==============================] - 1s 22ms/step - loss: 3.0806e-04 - accuracy: 1.0000 - val_loss: 6.3654e-04 - val_accuracy: 1.0000
# Epoch 134/200
# 58/58 [==============================] - 1s 22ms/step - loss: 5.3879e-04 - accuracy: 1.0000 - val_loss: 6.2557e-04 - val_accuracy: 1.0000
# Epoch 135/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0021 - accuracy: 0.9989 - val_loss: 5.0605e-04 - val_accuracy: 1.0000
# Epoch 136/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0079 - accuracy: 0.9989 - val_loss: 6.8609e-04 - val_accuracy: 1.0000
# Epoch 137/200
# 58/58 [==============================] - 1s 25ms/step - loss: 8.8317e-04 - accuracy: 1.0000 - val_loss: 5.5077e-04 - val_accuracy: 1.0000
# Epoch 138/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 5.2476e-04 - val_accuracy: 1.0000
# Epoch 139/200
# 58/58 [==============================] - 1s 23ms/step - loss: 3.0637e-04 - accuracy: 1.0000 - val_loss: 4.7790e-04 - val_accuracy: 1.0000
# Epoch 140/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0065 - accuracy: 0.9989 - val_loss: 6.7935e-04 - val_accuracy: 1.0000
# Epoch 141/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0127 - accuracy: 0.9946 - val_loss: 5.9922e-04 - val_accuracy: 1.0000
# Epoch 142/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 5.0004e-04 - val_accuracy: 1.0000
# Epoch 143/200
# 58/58 [==============================] - 1s 23ms/step - loss: 1.7103e-04 - accuracy: 1.0000 - val_loss: 4.8151e-04 - val_accuracy: 1.0000
# Epoch 144/200
# 58/58 [==============================] - 1s 24ms/step - loss: 2.5692e-04 - accuracy: 1.0000 - val_loss: 4.5201e-04 - val_accuracy: 1.0000
# Epoch 145/200
# 58/58 [==============================] - 1s 24ms/step - loss: 3.6114e-04 - accuracy: 1.0000 - val_loss: 4.2902e-04 - val_accuracy: 1.0000
# Epoch 146/200
# 58/58 [==============================] - 1s 24ms/step - loss: 1.7086e-04 - accuracy: 1.0000 - val_loss: 4.0918e-04 - val_accuracy: 1.0000
# Epoch 147/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0106 - accuracy: 0.9978 - val_loss: 9.4169e-04 - val_accuracy: 1.0000
# Epoch 148/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 6.2463e-04 - val_accuracy: 1.0000
# Epoch 149/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0079 - accuracy: 0.9967 - val_loss: 4.9284e-04 - val_accuracy: 1.0000
# Epoch 150/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0157 - accuracy: 0.9978 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 151/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0024 - accuracy: 0.9989 - val_loss: 8.7385e-04 - val_accuracy: 1.0000
# Epoch 152/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0013 - accuracy: 0.9989 - val_loss: 5.6144e-04 - val_accuracy: 1.0000
# Epoch 153/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0172 - accuracy: 0.9957 - val_loss: 9.6489e-04 - val_accuracy: 1.0000
# Epoch 154/200
# 58/58 [==============================] - 1s 24ms/step - loss: 3.9206e-04 - accuracy: 1.0000 - val_loss: 7.4465e-04 - val_accuracy: 1.0000
# Epoch 155/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0142 - accuracy: 0.9957 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 156/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 6.9587e-04 - val_accuracy: 1.0000
# Epoch 157/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0121 - accuracy: 0.9978 - val_loss: 8.1066e-04 - val_accuracy: 1.0000
# Epoch 158/200
# 58/58 [==============================] - 1s 24ms/step - loss: 2.2414e-04 - accuracy: 1.0000 - val_loss: 7.0898e-04 - val_accuracy: 1.0000
# Epoch 159/200
# 58/58 [==============================] - 1s 24ms/step - loss: 2.1207e-04 - accuracy: 1.0000 - val_loss: 6.6385e-04 - val_accuracy: 1.0000
# Epoch 160/200
# 58/58 [==============================] - 1s 23ms/step - loss: 4.9111e-04 - accuracy: 1.0000 - val_loss: 5.7869e-04 - val_accuracy: 1.0000
# Epoch 161/200
# 58/58 [==============================] - 1s 23ms/step - loss: 3.4417e-04 - accuracy: 1.0000 - val_loss: 5.4723e-04 - val_accuracy: 1.0000
# Epoch 162/200
# 58/58 [==============================] - 1s 24ms/step - loss: 1.8598e-04 - accuracy: 1.0000 - val_loss: 5.1954e-04 - val_accuracy: 1.0000
# Epoch 163/200
# 58/58 [==============================] - 1s 23ms/step - loss: 1.3547e-04 - accuracy: 1.0000 - val_loss: 5.0024e-04 - val_accuracy: 1.0000
# Epoch 164/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0158 - accuracy: 0.9957 - val_loss: 9.4681e-04 - val_accuracy: 1.0000
# Epoch 165/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 8.5168e-04 - val_accuracy: 1.0000
# Epoch 166/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 167/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0020 - accuracy: 0.9989 - val_loss: 6.9520e-04 - val_accuracy: 1.0000
# Epoch 168/200
# 58/58 [==============================] - 1s 23ms/step - loss: 2.8737e-04 - accuracy: 1.0000 - val_loss: 6.5580e-04 - val_accuracy: 1.0000
# Epoch 169/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 6.0881e-04 - val_accuracy: 1.0000
# Epoch 170/200
# 58/58 [==============================] - 1s 23ms/step - loss: 3.4654e-04 - accuracy: 1.0000 - val_loss: 5.0758e-04 - val_accuracy: 1.0000
# Epoch 171/200
# 58/58 [==============================] - 1s 23ms/step - loss: 2.4288e-04 - accuracy: 1.0000 - val_loss: 4.5860e-04 - val_accuracy: 1.0000
# Epoch 172/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0144 - accuracy: 0.9967 - val_loss: 8.1598e-04 - val_accuracy: 1.0000
# Epoch 173/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 4.5585e-04 - val_accuracy: 1.0000
# Epoch 174/200
# 58/58 [==============================] - 1s 23ms/step - loss: 4.2296e-04 - accuracy: 1.0000 - val_loss: 4.0312e-04 - val_accuracy: 1.0000
# Epoch 175/200
# 58/58 [==============================] - 1s 22ms/step - loss: 2.1573e-04 - accuracy: 1.0000 - val_loss: 3.7791e-04 - val_accuracy: 1.0000
# Epoch 176/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 4.6816e-04 - val_accuracy: 1.0000
# Epoch 177/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0055 - accuracy: 0.9989 - val_loss: 5.6317e-04 - val_accuracy: 1.0000
# Epoch 178/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 5.9818e-04 - val_accuracy: 1.0000
# Epoch 179/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.6175e-04 - val_accuracy: 1.0000
# Epoch 180/200
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 181/200
# 58/58 [==============================] - 1s 23ms/step - loss: 8.6374e-04 - accuracy: 1.0000 - val_loss: 4.3735e-04 - val_accuracy: 1.0000
# Epoch 182/200
# 58/58 [==============================] - 1s 24ms/step - loss: 4.3139e-04 - accuracy: 1.0000 - val_loss: 3.5865e-04 - val_accuracy: 1.0000
# Epoch 183/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 184/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0349 - accuracy: 0.9967 - val_loss: 4.0629e-04 - val_accuracy: 1.0000
# Epoch 185/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 186/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0059 - accuracy: 0.9989 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 187/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 188/200
# 58/58 [==============================] - 1s 24ms/step - loss: 4.2545e-04 - accuracy: 1.0000 - val_loss: 9.9126e-04 - val_accuracy: 1.0000
# Epoch 189/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 190/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0088 - accuracy: 0.9978 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 191/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 8.3208e-04 - val_accuracy: 1.0000
# Epoch 192/200
# 58/58 [==============================] - 1s 23ms/step - loss: 6.2724e-04 - accuracy: 1.0000 - val_loss: 6.9230e-04 - val_accuracy: 1.0000
# Epoch 193/200
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 5.7132e-04 - val_accuracy: 1.0000
# Epoch 194/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0098 - accuracy: 0.9978 - val_loss: 7.1773e-04 - val_accuracy: 1.0000
# Epoch 195/200
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 6.8835e-04 - val_accuracy: 1.0000
# Epoch 196/200
# 58/58 [==============================] - 1s 23ms/step - loss: 4.5769e-04 - accuracy: 1.0000 - val_loss: 5.6753e-04 - val_accuracy: 1.0000
# Epoch 197/200
# 58/58 [==============================] - 1s 23ms/step - loss: 2.5603e-04 - accuracy: 1.0000 - val_loss: 5.1773e-04 - val_accuracy: 1.0000
# Epoch 198/200
# 58/58 [==============================] - 1s 24ms/step - loss: 3.7461e-04 - accuracy: 1.0000 - val_loss: 4.7022e-04 - val_accuracy: 1.0000
# Epoch 199/200
# 58/58 [==============================] - 1s 24ms/step - loss: 1.7893e-04 - accuracy: 1.0000 - val_loss: 4.4644e-04 - val_accuracy: 1.0000
# Epoch 200/200
# 58/58 [==============================] - 1s 24ms/step - loss: 2.6770e-04 - accuracy: 1.0000 - val_loss: 4.2378e-04 - val_accuracy: 1.0000
# Training time: 278.254 sec
# Score for train dataset
# 29/29 [==============================] - 1s 17ms/step - loss: 4.4410e-04 - accuracy: 1.0000
# Score:
# loss : 0.000444099452579394
# loss : 100.0 %

# %%
def plotHistory(history, train, validation):
    """
        plot training history
        Parameters
        ------------------------------
        history = history
        train = 'accuracy' or 'loss'
        validation = 'val_accuracy' or 'val_loss'
    """
    plt.figure(figsize= (8, 6))
    plt.plot(history.history[train])
    plt.plot(history.history[validation])
    plt.legend(['train', 'validation'], loc= 'center right')
    plt.xlabel("Epochs")
    if train == 'accuracy':
        plt.ylabel("Accuracy")
        plt.title(f"Accuracy for train dataset")
    elif train == "loss":
        plt.ylabel("Loss")
        plt.title("Loss for train dataset")
    plt.show()

# %%
plotHistory(history= history, train= 'accuracy', validation= 'val_accuracy')
plotHistory(history= history, train= 'loss', validation= 'val_loss')

# %%
# Evaluate test dataset
testScore = model.evaluate(X_test, testTargets, verbose= 1)
print(f"{model.metrics_names[0]} : {testScore[0]}\n{model.metrics_names[1]} : {testScore[1] * 100} %")

# %%
# Prediction for test dataset

prediction = model.predict(X_test)
predictionClass = np.argmax(prediction, axis= 1)        # One-hot encoding --> Original label

# Actual Class (One-hot encoding testTarget --> y_test)
if testTargets.ndim > 1:
    actualClass = np.argmax(testTargets, axis= 1)
else:
    actualClass = testTargets

# Classification report
print(f"Classification report: \n{classification_report(actualClass, predictionClass)}")

# Confusion matrix
plt.figure(figsize= (8, 6))
sns.heatmap(confusion_matrix(actualClass, predictionClass), 
            annot= True, 
            fmt= "d", 
            cmap= "Blues",
            cbar= False)
plt.title("Confusion matrix for test dataset")
plt.xlabel("Prediction class")
plt.ylabel("Actual class")
plt.show()
# Out:
# 9/9 [==============================] - 1s 6ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        72
#            1       1.00      1.00      1.00        72
#            2       1.00      1.00      1.00        72
#            3       1.00      1.00      1.00        72
#
#     accuracy                           1.00       288
#    macro avg       1.00      1.00      1.00       288
# weighted avg       1.00      1.00      1.00       288

# %%
# Prediction for 1 image

randomImgIdx = random.randrange(0, X_test.shape[0])

predictStartTime = time.time()

predictionImg = X_test[randomImgIdx]
predictionImg = np.expand_dims(predictionImg, axis= 0)

testPrediction = model.predict(predictionImg)

predictEndTime = time.time()

print("Random image index: ", randomImgIdx)
print("Random actual label: ", i_test[randomImgIdx])
print("Random actual class: ", actualClass[randomImgIdx])
print("Random prediction class: ", predictionClass[randomImgIdx])
# Out:
# 1/1 [==============================] - 1s 845ms/step
# Random image index:  84
# Random actual label:  L_58
# Random actual class:  2
# Random prediction class:  2
