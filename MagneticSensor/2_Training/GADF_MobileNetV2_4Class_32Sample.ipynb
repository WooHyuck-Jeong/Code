# %%
import os
import glob
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import keras
import tensorflow as tf
from keras import optimizers
from keras.utils import to_categorical
from keras.layers import Dense, Input
from keras.models import Model, load_model
from keras.applications import MobileNetV2
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
dataPath = "../1_Data_Preprocessing/32Sample/4Class/GADF_4Class_32Sample.npz"
data = np.load(dataPath)

X_data = data['X_data']
y_data = data['y_data']
i_data = data['i_data']

data.close()

print("X_data: ", X_data.shape)
print("y_data: ", y_data.shape)
print("i_data: ", i_data.shape)
# Out:
# X_data:  (1440, 32, 32, 3)
# y_data:  (1440,)
# i_data:  (1440,)

# %%
# Data split

# Set random seed for reproductivity
seed = 42

# Train - Test split
X_train, X_test, y_train, y_test, i_train, i_test = train_test_split(X_data, y_data, i_data, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_data)

# Train - Validation split
X_train, X_val, y_train, y_val, i_train, i_val = train_test_split(X_train, y_train, i_train, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_train)

print(X_train.shape, X_test.shape, X_val.shape)
print(y_train.shape, y_test.shape, y_val.shape)
print(i_train.shape, i_test.shape, i_val.shape)

print(np.unique(y_train, return_counts= True))
print(np.unique(y_test, return_counts= True))
print(np.unique(y_val, return_counts= True))
# Out:
# (921, 32, 32, 3) (288, 32, 32, 3) (231, 32, 32, 3)
# (921,) (288,) (231,)
# (921,) (288,) (231,)
# (array([0, 1, 2, 3]), array([230, 231, 230, 230], dtype=int64))
# (array([0, 1, 2, 3]), array([72, 72, 72, 72], dtype=int64))
# (array([0, 1, 2, 3]), array([58, 57, 58, 58], dtype=int64))

# %%
# One - hot encoding
trainTargets = to_categorical(y_train)
testTargets = to_categorical(y_test)
valTargets = to_categorical(y_val)

print("Train targets: ", trainTargets.shape)
print("Test targets: ", testTargets.shape)
print("Validation targets: ", valTargets.shape)
# Out:
# Train targets:  (921, 4)
# Test targets:  (288, 4)
# Validation targets:  (231, 4)

# %%
weightPath = "./weights/"

# %%
# MobileNetV2 Transfer-learning
# Import convolution layer
# weight = None

with tf.device("/device:GPU:0"):
    inputTensor = Input(shape= (32, 32, 3))

    model = MobileNetV2(input_tensor= inputTensor,              # Input data shape
                        include_top= False,                     # Only convolution layer. If True: Use Classification layer
                        weights= None,                          # If weights= "imagenet" --> Use imagenet weights
                        pooling= 'max')

    x = model.output
    x = Dense(4, activation= 'softmax', kernel_initializer= 'he_normal')(x)

    model = Model(model.input, x)

    # Instantiate optimizer
    optim = optimizers.SGD(learning_rate= 0.01,
                           decay= 1e-3,
                           momentum= 0.9,
                           nesterov= True)

    # Compile model
    model.compile(optimizer= optim,
                  loss= 'categorical_crossentropy',
                  metrics= ['accuracy'])

    print("Training======================================")
    startTime = time.time()                                     # Training start time

    history = model.fit(X_train, trainTargets,
                        batch_size= 16,
                        epochs= 150,
                        verbose= 1,
                        validation_data= (X_val, valTargets)
                        )
    
    endTime = time.time()                                       # Training end time
    print(f"Training time: {np.round(endTime - startTime, 3)} sec")

    # save weight file
    model.save(os.path.join(weightPath, "GADF_MobileNetV2_4Class_32Sample.h5"))

    # Evaluate for total train dataset
    print("Score for train dataset")
    score = model.evaluate(X_train, trainTargets, verbose= 1)
    print(f"Score: \n{model.metrics_names[0]} : {score[0]}\n{model.metrics_names[0]} : {score[1] * 100} %")
# Out:
# Training======================================
# Epoch 1/150
# 58/58 [==============================] - 9s 52ms/step - loss: 1.1258 - accuracy: 0.6699 - val_loss: 1.3892 - val_accuracy: 0.2511
# Epoch 2/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.3207 - accuracy: 0.9088 - val_loss: 1.4087 - val_accuracy: 0.2511
# Epoch 3/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.1609 - accuracy: 0.9555 - val_loss: 1.4053 - val_accuracy: 0.2511
# Epoch 4/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.1857 - accuracy: 0.9577 - val_loss: 1.4230 - val_accuracy: 0.2511
# Epoch 5/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.1552 - accuracy: 0.9555 - val_loss: 1.4071 - val_accuracy: 0.2511
# Epoch 6/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2139 - accuracy: 0.9598 - val_loss: 1.4328 - val_accuracy: 0.2511
# Epoch 7/150
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1008 - accuracy: 0.9837 - val_loss: 1.4248 - val_accuracy: 0.2511
# Epoch 8/150
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1696 - accuracy: 0.9696 - val_loss: 1.4250 - val_accuracy: 0.2511
# Epoch 9/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0744 - accuracy: 0.9837 - val_loss: 1.4217 - val_accuracy: 0.2511
# Epoch 10/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0819 - accuracy: 0.9837 - val_loss: 1.4531 - val_accuracy: 0.2511
# Epoch 11/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0125 - accuracy: 0.9978 - val_loss: 1.4647 - val_accuracy: 0.2511
# Epoch 12/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0627 - accuracy: 0.9891 - val_loss: 1.4743 - val_accuracy: 0.2511
# Epoch 13/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.1223 - accuracy: 0.9891 - val_loss: 1.4266 - val_accuracy: 0.2511
# Epoch 14/150
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0132 - accuracy: 0.9957 - val_loss: 1.4581 - val_accuracy: 0.2511
# Epoch 15/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0184 - accuracy: 0.9957 - val_loss: 1.4694 - val_accuracy: 0.2511
# Epoch 16/150
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0708 - accuracy: 0.9913 - val_loss: 1.4876 - val_accuracy: 0.2511
# Epoch 17/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0207 - accuracy: 0.9967 - val_loss: 1.5498 - val_accuracy: 0.2468
# Epoch 18/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0091 - accuracy: 0.9957 - val_loss: 1.5607 - val_accuracy: 0.2511
# Epoch 19/150
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0354 - accuracy: 0.9913 - val_loss: 1.5958 - val_accuracy: 0.2511
# Epoch 20/150
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.6181 - val_accuracy: 0.2511
# Epoch 21/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0357 - accuracy: 0.9967 - val_loss: 1.5923 - val_accuracy: 0.2468
# Epoch 22/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0339 - accuracy: 0.9935 - val_loss: 1.6478 - val_accuracy: 0.2511
# Epoch 23/150
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0556 - accuracy: 0.9957 - val_loss: 1.6378 - val_accuracy: 0.2511
# Epoch 24/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0263 - accuracy: 0.9924 - val_loss: 1.6084 - val_accuracy: 0.2511
# Epoch 25/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0152 - accuracy: 0.9967 - val_loss: 1.6010 - val_accuracy: 0.2511
# Epoch 26/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0352 - accuracy: 0.9957 - val_loss: 1.6177 - val_accuracy: 0.3420
# Epoch 27/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.6420 - val_accuracy: 0.2511
# Epoch 28/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0278 - accuracy: 0.9957 - val_loss: 1.6402 - val_accuracy: 0.2511
# Epoch 29/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0423 - accuracy: 0.9924 - val_loss: 1.6000 - val_accuracy: 0.2511
# Epoch 30/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0146 - accuracy: 0.9957 - val_loss: 1.7077 - val_accuracy: 0.2511
# Epoch 31/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0138 - accuracy: 0.9978 - val_loss: 1.7014 - val_accuracy: 0.2511
# Epoch 32/150
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0144 - accuracy: 0.9989 - val_loss: 1.7348 - val_accuracy: 0.2511
# Epoch 33/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0149 - accuracy: 0.9989 - val_loss: 1.7516 - val_accuracy: 0.2511
# Epoch 34/150
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.7628 - val_accuracy: 0.2511
# Epoch 35/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0128 - accuracy: 0.9946 - val_loss: 1.7996 - val_accuracy: 0.2511
# Epoch 36/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0146 - accuracy: 0.9967 - val_loss: 1.8027 - val_accuracy: 0.2511
# Epoch 37/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0192 - accuracy: 0.9978 - val_loss: 1.8936 - val_accuracy: 0.2511
# Epoch 38/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 1.8689 - val_accuracy: 0.2511
# Epoch 39/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0141 - accuracy: 0.9978 - val_loss: 1.8309 - val_accuracy: 0.3247
# Epoch 40/150
# 58/58 [==============================] - 1s 24ms/step - loss: 4.9981e-04 - accuracy: 1.0000 - val_loss: 1.8424 - val_accuracy: 0.2987
# Epoch 41/150
# 58/58 [==============================] - 1s 23ms/step - loss: 3.7434e-04 - accuracy: 1.0000 - val_loss: 1.8527 - val_accuracy: 0.3377
# Epoch 42/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0033 - accuracy: 0.9978 - val_loss: 1.8522 - val_accuracy: 0.4892
# Epoch 43/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0052 - accuracy: 0.9978 - val_loss: 1.8431 - val_accuracy: 0.4978
# Epoch 44/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 1.8718 - val_accuracy: 0.4978
# Epoch 45/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0130 - accuracy: 0.9989 - val_loss: 1.8923 - val_accuracy: 0.4978
# Epoch 46/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0090 - accuracy: 0.9989 - val_loss: 1.8618 - val_accuracy: 0.4978
# Epoch 47/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.8546 - val_accuracy: 0.4978
# Epoch 48/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.8419 - val_accuracy: 0.4978
# Epoch 49/150
# 58/58 [==============================] - 1s 23ms/step - loss: 2.0902e-04 - accuracy: 1.0000 - val_loss: 1.8271 - val_accuracy: 0.4978
# Epoch 50/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0147 - accuracy: 0.9978 - val_loss: 1.8748 - val_accuracy: 0.2511
# Epoch 51/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0171 - accuracy: 0.9967 - val_loss: 1.8841 - val_accuracy: 0.2511
# Epoch 52/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0114 - accuracy: 0.9967 - val_loss: 1.8631 - val_accuracy: 0.2511
# Epoch 53/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.7937 - val_accuracy: 0.4978
# Epoch 54/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 1.7114 - val_accuracy: 0.4978
# Epoch 55/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0015 - accuracy: 0.9989 - val_loss: 1.6816 - val_accuracy: 0.4978
# Epoch 56/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 1.5760 - val_accuracy: 0.4978
# Epoch 57/150
# 58/58 [==============================] - 1s 25ms/step - loss: 7.2730e-04 - accuracy: 1.0000 - val_loss: 1.5461 - val_accuracy: 0.4978
# Epoch 58/150
# 58/58 [==============================] - 1s 24ms/step - loss: 7.8471e-04 - accuracy: 1.0000 - val_loss: 1.5266 - val_accuracy: 0.4978
# Epoch 59/150
# 58/58 [==============================] - 1s 24ms/step - loss: 2.0783e-04 - accuracy: 1.0000 - val_loss: 1.4929 - val_accuracy: 0.4978
# Epoch 60/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0082 - accuracy: 0.9989 - val_loss: 1.4333 - val_accuracy: 0.4978
# Epoch 61/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0165 - accuracy: 0.9978 - val_loss: 1.4176 - val_accuracy: 0.4978
# Epoch 62/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3938 - val_accuracy: 0.4978
# Epoch 63/150
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 1.3625 - val_accuracy: 0.4978
# Epoch 64/150
# 58/58 [==============================] - 1s 23ms/step - loss: 8.3303e-04 - accuracy: 1.0000 - val_loss: 1.3400 - val_accuracy: 0.4978
# Epoch 65/150
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0018 - accuracy: 0.9989 - val_loss: 1.3008 - val_accuracy: 0.4978
# Epoch 66/150
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0098 - accuracy: 0.9978 - val_loss: 1.2374 - val_accuracy: 0.4978
# Epoch 67/150
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0087 - accuracy: 0.9967 - val_loss: 1.2036 - val_accuracy: 0.4978
# Epoch 68/150
# 58/58 [==============================] - 1s 24ms/step - loss: 5.5511e-04 - accuracy: 1.0000 - val_loss: 1.1392 - val_accuracy: 0.4978
# Epoch 69/150
# 58/58 [==============================] - 1s 24ms/step - loss: 5.4381e-04 - accuracy: 1.0000 - val_loss: 1.0847 - val_accuracy: 0.4978
# Epoch 70/150
# 58/58 [==============================] - 1s 24ms/step - loss: 1.9190e-04 - accuracy: 1.0000 - val_loss: 1.0306 - val_accuracy: 0.4978
# Epoch 71/150
# 58/58 [==============================] - 1s 25ms/step - loss: 6.7822e-04 - accuracy: 1.0000 - val_loss: 0.9781 - val_accuracy: 0.4978
# Epoch 72/150
# 58/58 [==============================] - 1s 24ms/step - loss: 1.9262e-04 - accuracy: 1.0000 - val_loss: 0.9243 - val_accuracy: 0.4978
# Epoch 73/150
# 58/58 [==============================] - 1s 25ms/step - loss: 5.3118e-04 - accuracy: 1.0000 - val_loss: 0.8791 - val_accuracy: 0.4978
# Epoch 74/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.8434 - val_accuracy: 0.4978
# Epoch 75/150
# 58/58 [==============================] - 1s 24ms/step - loss: 2.1802e-04 - accuracy: 1.0000 - val_loss: 0.7873 - val_accuracy: 0.4978
# Epoch 76/150
# 58/58 [==============================] - 1s 24ms/step - loss: 1.1475e-04 - accuracy: 1.0000 - val_loss: 0.7299 - val_accuracy: 0.4978
# Epoch 77/150
# 58/58 [==============================] - 1s 24ms/step - loss: 2.6227e-04 - accuracy: 1.0000 - val_loss: 0.6779 - val_accuracy: 0.5022
# Epoch 78/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0025 - accuracy: 0.9989 - val_loss: 0.6298 - val_accuracy: 0.5584
# Epoch 79/150
# 58/58 [==============================] - 1s 24ms/step - loss: 9.6252e-04 - accuracy: 1.0000 - val_loss: 0.5914 - val_accuracy: 0.5108
# Epoch 80/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0027 - accuracy: 0.9978 - val_loss: 0.5590 - val_accuracy: 0.6926
# Epoch 81/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0064 - accuracy: 0.9967 - val_loss: 0.5053 - val_accuracy: 0.7792
# Epoch 82/150
# 58/58 [==============================] - 1s 24ms/step - loss: 8.7310e-04 - accuracy: 1.0000 - val_loss: 0.4484 - val_accuracy: 0.8745
# Epoch 83/150
# 58/58 [==============================] - 1s 24ms/step - loss: 7.8562e-04 - accuracy: 1.0000 - val_loss: 0.3943 - val_accuracy: 0.9437
# Epoch 84/150
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.3589 - val_accuracy: 0.9697
# Epoch 85/150
# 58/58 [==============================] - 1s 23ms/step - loss: 1.8623e-04 - accuracy: 1.0000 - val_loss: 0.3176 - val_accuracy: 1.0000
# Epoch 86/150
# 58/58 [==============================] - 1s 24ms/step - loss: 3.6117e-04 - accuracy: 1.0000 - val_loss: 0.2795 - val_accuracy: 1.0000
# Epoch 87/150
# 58/58 [==============================] - 1s 24ms/step - loss: 4.9846e-04 - accuracy: 1.0000 - val_loss: 0.2448 - val_accuracy: 1.0000
# Epoch 88/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 1.0000
# Epoch 89/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0013 - accuracy: 0.9989 - val_loss: 0.1796 - val_accuracy: 1.0000
# Epoch 90/150
# 58/58 [==============================] - 1s 24ms/step - loss: 2.9542e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 1.0000
# Epoch 91/150
# 58/58 [==============================] - 1s 24ms/step - loss: 1.9085e-04 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 1.0000
# Epoch 92/150
# 58/58 [==============================] - 1s 24ms/step - loss: 4.8209e-04 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 1.0000
# Epoch 93/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0014 - accuracy: 0.9989 - val_loss: 0.1026 - val_accuracy: 1.0000
# Epoch 94/150
# 58/58 [==============================] - 1s 23ms/step - loss: 4.9923e-04 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 1.0000
# Epoch 95/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0046 - accuracy: 0.9967 - val_loss: 0.0882 - val_accuracy: 1.0000
# Epoch 96/150
# 58/58 [==============================] - 1s 24ms/step - loss: 5.8252e-04 - accuracy: 1.0000 - val_loss: 0.0718 - val_accuracy: 1.0000
# Epoch 97/150
# 58/58 [==============================] - 1s 24ms/step - loss: 3.8588e-04 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 1.0000
# Epoch 98/150
# 58/58 [==============================] - 1s 23ms/step - loss: 2.4026e-04 - accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 1.0000
# Epoch 99/150
# 58/58 [==============================] - 1s 23ms/step - loss: 7.8917e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 1.0000
# Epoch 100/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0173 - accuracy: 0.9924 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 101/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 102/150
# 58/58 [==============================] - 1s 23ms/step - loss: 4.0469e-04 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 103/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 104/150
# 58/58 [==============================] - 1s 23ms/step - loss: 3.9697e-04 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 105/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0236 - accuracy: 0.9989 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 106/150
# 58/58 [==============================] - 1s 24ms/step - loss: 7.0918e-04 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 107/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0030 - accuracy: 0.9978 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 108/150
# 58/58 [==============================] - 1s 23ms/step - loss: 6.7821e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 109/150
# 58/58 [==============================] - 1s 24ms/step - loss: 7.6705e-04 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 110/150
# 58/58 [==============================] - 1s 23ms/step - loss: 2.5816e-04 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 111/150
# 58/58 [==============================] - 1s 23ms/step - loss: 2.2804e-04 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 112/150
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0322 - accuracy: 0.9978 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 113/150
# 58/58 [==============================] - 1s 25ms/step - loss: 9.8010e-04 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 114/150
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 115/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 116/150
# 58/58 [==============================] - 1s 24ms/step - loss: 5.1049e-04 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 117/150
# 58/58 [==============================] - 1s 24ms/step - loss: 5.7484e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 118/150
# 58/58 [==============================] - 1s 23ms/step - loss: 4.1110e-04 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 119/150
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 120/150
# 58/58 [==============================] - 1s 24ms/step - loss: 2.3706e-04 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 121/150
# 58/58 [==============================] - 1s 24ms/step - loss: 3.5973e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 122/150
# 58/58 [==============================] - 1s 22ms/step - loss: 1.3231e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 123/150
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0125 - accuracy: 0.9978 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 124/150
# 58/58 [==============================] - 1s 22ms/step - loss: 3.8421e-04 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 125/150
# 58/58 [==============================] - 1s 22ms/step - loss: 2.1320e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 126/150
# 58/58 [==============================] - 1s 23ms/step - loss: 7.9461e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 127/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 128/150
# 58/58 [==============================] - 1s 24ms/step - loss: 3.9018e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 129/150
# 58/58 [==============================] - 1s 24ms/step - loss: 2.4514e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 130/150
# 58/58 [==============================] - 1s 24ms/step - loss: 2.6609e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 131/150
# 58/58 [==============================] - 1s 24ms/step - loss: 1.3257e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 132/150
# 58/58 [==============================] - 1s 24ms/step - loss: 2.2359e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 133/150
# 58/58 [==============================] - 1s 24ms/step - loss: 1.0843e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 134/150
# 58/58 [==============================] - 1s 24ms/step - loss: 5.5397e-04 - accuracy: 1.0000 - val_loss: 9.8863e-04 - val_accuracy: 1.0000
# Epoch 135/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0148 - accuracy: 0.9989 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 136/150
# 58/58 [==============================] - 1s 24ms/step - loss: 2.8307e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 137/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0019 - accuracy: 0.9989 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 138/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 139/150
# 58/58 [==============================] - 1s 23ms/step - loss: 4.0636e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 140/150
# 58/58 [==============================] - 1s 24ms/step - loss: 3.2923e-04 - accuracy: 1.0000 - val_loss: 9.4297e-04 - val_accuracy: 1.0000
# Epoch 141/150
# 58/58 [==============================] - 1s 24ms/step - loss: 4.0183e-04 - accuracy: 1.0000 - val_loss: 8.3892e-04 - val_accuracy: 1.0000
# Epoch 142/150
# 58/58 [==============================] - 1s 24ms/step - loss: 2.3500e-04 - accuracy: 1.0000 - val_loss: 7.5212e-04 - val_accuracy: 1.0000
# Epoch 143/150
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0018 - accuracy: 0.9989 - val_loss: 8.9935e-04 - val_accuracy: 1.0000
# Epoch 144/150
# 58/58 [==============================] - 1s 24ms/step - loss: 5.8385e-04 - accuracy: 1.0000 - val_loss: 8.1502e-04 - val_accuracy: 1.0000
# Epoch 145/150
# 58/58 [==============================] - 1s 23ms/step - loss: 2.3575e-04 - accuracy: 1.0000 - val_loss: 7.2377e-04 - val_accuracy: 1.0000
# Epoch 146/150
# 58/58 [==============================] - 1s 24ms/step - loss: 2.9205e-04 - accuracy: 1.0000 - val_loss: 6.5091e-04 - val_accuracy: 1.0000
# Epoch 147/150
# 58/58 [==============================] - 1s 23ms/step - loss: 7.5515e-05 - accuracy: 1.0000 - val_loss: 6.0795e-04 - val_accuracy: 1.0000
# Epoch 148/150
# 58/58 [==============================] - 1s 23ms/step - loss: 7.6852e-05 - accuracy: 1.0000 - val_loss: 5.6918e-04 - val_accuracy: 1.0000
# Epoch 149/150
# 58/58 [==============================] - 1s 23ms/step - loss: 1.1277e-04 - accuracy: 1.0000 - val_loss: 5.2410e-04 - val_accuracy: 1.0000
# Epoch 150/150
# 58/58 [==============================] - 1s 24ms/step - loss: 5.6590e-05 - accuracy: 1.0000 - val_loss: 4.9595e-04 - val_accuracy: 1.0000
# Training time: 214.43 sec
# Score for train dataset
# 29/29 [==============================] - 1s 17ms/step - loss: 5.1519e-04 - accuracy: 1.0000
# Score:
# loss : 0.0005151923978701234
# loss : 100.0 %

# %%
def plotHistory(history, train, validation):
    """
        plot training history
        Parameters
        ------------------------------
        history = history
        train = 'accuracy' or 'loss'
        validation = 'val_accuracy' or 'val_loss'
    """
    plt.figure(figsize= (8, 6))
    plt.plot(history.history[train])
    plt.plot(history.history[validation])
    plt.legend(['train', 'validation'], loc= 'center right')
    plt.xlabel("Epochs")
    if train == 'accuracy':
        plt.ylabel("Accuracy")
        plt.title(f"Accuracy for train dataset")
    elif train == "loss":
        plt.ylabel("Loss")
        plt.title("Loss for train dataset")
    plt.show()

# %%
plotHistory(history= history, train= 'accuracy', validation= 'val_accuracy')
plotHistory(history= history, train= 'loss', validation= 'val_loss')

# %%
# Evaluate test dataset
testScore = model.evaluate(X_test, testTargets, verbose= 1)
print(f"{model.metrics_names[0]} : {testScore[0]}\n{model.metrics_names[1]} : {testScore[1] * 100} %")
# Out:
# 9/9 [==============================] - 0s 7ms/step - loss: 5.7835e-04 - accuracy: 1.0000
# loss : 0.0005783478263765574
# accuracy : 100.0 %

# %%
# Prediction for test dataset

prediction = model.predict(X_test)
predictionClass = np.argmax(prediction, axis= 1)        # One-hot encoding --> Original label

# Actual Class (One-hot encoding testTarget --> y_test)
if testTargets.ndim > 1:
    actualClass = np.argmax(testTargets, axis= 1)
else:
    actualClass = testTargets

# Classification report
print(f"Classification report: \n{classification_report(actualClass, predictionClass)}")

# Confusion matrix
plt.figure(figsize= (8, 6))
sns.heatmap(confusion_matrix(actualClass, predictionClass), 
            annot= True, 
            fmt= "d", 
            cmap= "Blues",
            cbar= False)
plt.title("Confusion matrix for test dataset")
plt.xlabel("Prediction class")
plt.ylabel("Actual class")
plt.show()
# Out:
# 9/9 [==============================] - 1s 6ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        72
#            1       1.00      1.00      1.00        72
#            2       1.00      1.00      1.00        72
#            3       1.00      1.00      1.00        72
#
#     accuracy                           1.00       288
#    macro avg       1.00      1.00      1.00       288
# weighted avg       1.00      1.00      1.00       288

# %%
# Prediction for 1 image

randomImgIdx = random.randrange(0, X_test.shape[0])

predictStartTime = time.time()

predictionImg = X_test[randomImgIdx]
predictionImg = np.expand_dims(predictionImg, axis= 0)

testPrediction = model.predict(predictionImg)

predictEndTime = time.time()

print("Random image index: ", randomImgIdx)
print("Random actual label: ", i_test[randomImgIdx])
print("Random actual class: ", actualClass[randomImgIdx])
print("Random prediction class: ", predictionClass[randomImgIdx])
# Out:
# 1/1 [==============================] - 1s 919ms/step
# Random image index:  118
# Random actual label:  L_109
# Random actual class:  2
# Random prediction class:  2
