# %%
import os
import glob
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import keras
import tensorflow as tf
from keras import optimizers
from keras.utils import to_categorical
from keras.layers import Dense, Input
from keras.models import Model, load_model
from keras.applications import MobileNetV2
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
dataPath = "GADF_3Class_16Sample_Nonclip.npz"
data = np.load(dataPath)

X_data = data['X_data']
y_data = data['y_data']
i_data = data['i_data']

data.close()

print("X_data: ", X_data.shape)
print("y_data: ", y_data.shape)
print("i_data: ", i_data.shape)
# Out:
# X_data:  (2160, 16, 16, 3)
# y_data:  (2160,)
# i_data:  (2160,)

# %%
# Data split

# Set random seed for reproductivity
seed = 42

# Train - Test split
X_train, X_test, y_train, y_test, i_train, i_test = train_test_split(X_data, y_data, i_data, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_data)

# Train - Validation split
X_train, X_val, y_train, y_val, i_train, i_val = train_test_split(X_train, y_train, i_train, test_size= 0.2, shuffle= True, random_state= seed, stratify= y_train)

print(X_train.shape, X_test.shape, X_val.shape)
print(y_train.shape, y_test.shape, y_val.shape)
print(i_train.shape, i_test.shape, i_val.shape)

print(np.unique(y_train, return_counts= True))
print(np.unique(y_test, return_counts= True))
print(np.unique(y_val, return_counts= True))
# Out:
# (1382, 16, 16, 3) (432, 16, 16, 3) (346, 16, 16, 3)
# (1382,) (432,) (346,)
# (1382,) (432,) (346,)
# (array([0, 1, 2]), array([461, 461, 460], dtype=int64))
# (array([0, 1, 2]), array([144, 144, 144], dtype=int64))
# (array([0, 1, 2]), array([115, 115, 116], dtype=int64))

# %%
# One - hot encoding
trainTargets = to_categorical(y_train)
testTargets = to_categorical(y_test)
valTargets = to_categorical(y_val)

print("Train targets: ", trainTargets.shape)
print("Test targets: ", testTargets.shape)
print("Validation targets: ", valTargets.shape)
# Out:
# Train targets:  (1382, 3)
# Test targets:  (432, 3)
# Validation targets:  (346, 3)

# %%
weightPath = "./weights/"

# %%
# MobileNetV2 Transfer-learning
# Import convolution layer
# weight = None

with tf.device("/device:GPU:0"):
    inputTensor = Input(shape= (16, 16, 3))

    model = MobileNetV2(input_tensor= inputTensor,              # Input data shape
                        include_top= False,                     # Only convolution layer. If True: Use Classification layer
                        weights= None,                          # If weights= "imagenet" --> Use imagenet weights
                        pooling= 'max')

    x = model.output
    x = Dense(3, activation= 'softmax', kernel_initializer= 'he_normal')(x)

    model = Model(model.input, x)

    # Instantiate optimizer
    optim = optimizers.SGD(learning_rate= 0.01,
                           decay= 1e-3,
                           momentum= 0.9,
                           nesterov= True)

    # Compile model
    model.compile(optimizer= optim,
                  loss= 'categorical_crossentropy',
                  metrics= ['accuracy'])

    print("Training======================================")
    startTime = time.time()                                     # Training start time

    history = model.fit(X_train, trainTargets,
                        batch_size= 16,
                        epochs= 150,
                        verbose= 1,
                        validation_data= (X_val, valTargets)
                        )
    
    endTime = time.time()                                       # Training end time
    print(f"Training time: {np.round(endTime - startTime, 3)} sec")

    # save weight file
    # model.save(os.path.join(weightPath, "GADF_MobileNetV2_3Class_16Sample.h5"))

    # Evaluate for total train dataset
    print("Score for train dataset")
    score = model.evaluate(X_train, trainTargets, verbose= 1)
    print(f"Score: \n{model.metrics_names[0]} : {score[0]}\n{model.metrics_names[0]} : {score[1] * 100} %")
# Out:
# Training======================================
# Epoch 1/150
# 87/87 [==============================] - 9s 42ms/step - loss: 0.7934 - accuracy: 0.7431 - val_loss: 1.1221 - val_accuracy: 0.3555
# Epoch 2/150
# 87/87 [==============================] - 2s 26ms/step - loss: 0.4156 - accuracy: 0.8705 - val_loss: 1.2332 - val_accuracy: 0.3324
# Epoch 3/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.2957 - accuracy: 0.9161 - val_loss: 1.1841 - val_accuracy: 0.3324
# Epoch 4/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.2065 - accuracy: 0.9450 - val_loss: 1.1437 - val_accuracy: 0.3324
# Epoch 5/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.1164 - accuracy: 0.9703 - val_loss: 1.1242 - val_accuracy: 0.3324
# Epoch 6/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.1166 - accuracy: 0.9645 - val_loss: 1.1085 - val_accuracy: 0.3324
# Epoch 7/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.1417 - accuracy: 0.9660 - val_loss: 1.1053 - val_accuracy: 0.2399
# Epoch 8/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.1093 - accuracy: 0.9645 - val_loss: 1.1058 - val_accuracy: 0.3324
# Epoch 9/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.1572 - accuracy: 0.9689 - val_loss: 1.1212 - val_accuracy: 0.3324
# Epoch 10/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.1119 - accuracy: 0.9718 - val_loss: 1.1374 - val_accuracy: 0.3324
# Epoch 11/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0939 - accuracy: 0.9761 - val_loss: 1.1341 - val_accuracy: 0.3324
# Epoch 12/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.1312 - accuracy: 0.9718 - val_loss: 1.1071 - val_accuracy: 0.3324
# Epoch 13/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0817 - accuracy: 0.9747 - val_loss: 1.1137 - val_accuracy: 0.3324
# Epoch 14/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.1206 - accuracy: 0.9682 - val_loss: 1.1498 - val_accuracy: 0.3324
# Epoch 15/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0974 - accuracy: 0.9776 - val_loss: 1.1307 - val_accuracy: 0.3324
# Epoch 16/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0650 - accuracy: 0.9841 - val_loss: 1.1191 - val_accuracy: 0.3324
# Epoch 17/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0642 - accuracy: 0.9935 - val_loss: 1.1060 - val_accuracy: 0.3642
# Epoch 18/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0399 - accuracy: 0.9928 - val_loss: 1.2301 - val_accuracy: 0.3324
# Epoch 19/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.1002 - accuracy: 0.9812 - val_loss: 1.2173 - val_accuracy: 0.3324
# Epoch 20/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0202 - accuracy: 0.9964 - val_loss: 1.2059 - val_accuracy: 0.3324
# Epoch 21/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0929 - accuracy: 0.9725 - val_loss: 1.1475 - val_accuracy: 0.3382
# Epoch 22/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0419 - accuracy: 0.9920 - val_loss: 1.2076 - val_accuracy: 0.3324
# Epoch 23/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0322 - accuracy: 0.9928 - val_loss: 1.1341 - val_accuracy: 0.3324
# Epoch 24/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0241 - accuracy: 0.9964 - val_loss: 1.0939 - val_accuracy: 0.3324
# Epoch 25/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0500 - accuracy: 0.9891 - val_loss: 1.0624 - val_accuracy: 0.3324
# Epoch 26/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0363 - accuracy: 0.9957 - val_loss: 1.0583 - val_accuracy: 0.3324
# Epoch 27/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0221 - accuracy: 0.9942 - val_loss: 1.1233 - val_accuracy: 0.3324
# Epoch 28/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0279 - accuracy: 0.9935 - val_loss: 1.1343 - val_accuracy: 0.3324
# Epoch 29/150
# 87/87 [==============================] - 2s 26ms/step - loss: 0.0305 - accuracy: 0.9942 - val_loss: 1.1046 - val_accuracy: 0.3324
# Epoch 30/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0639 - accuracy: 0.9863 - val_loss: 1.1468 - val_accuracy: 0.3324
# Epoch 31/150
# 87/87 [==============================] - 2s 26ms/step - loss: 0.0956 - accuracy: 0.9740 - val_loss: 1.0490 - val_accuracy: 0.4769
# Epoch 32/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0262 - accuracy: 0.9920 - val_loss: 0.9997 - val_accuracy: 0.3324
# Epoch 33/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0222 - accuracy: 0.9964 - val_loss: 1.0023 - val_accuracy: 0.3324
# Epoch 34/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0186 - accuracy: 0.9978 - val_loss: 0.9824 - val_accuracy: 0.5896
# Epoch 35/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0731 - accuracy: 0.9863 - val_loss: 0.9531 - val_accuracy: 0.6561
# Epoch 36/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0484 - accuracy: 0.9899 - val_loss: 0.9620 - val_accuracy: 0.6590
# Epoch 37/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0421 - accuracy: 0.9891 - val_loss: 0.9405 - val_accuracy: 0.6647
# Epoch 38/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.9467 - val_accuracy: 0.6647
# Epoch 39/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0190 - accuracy: 0.9949 - val_loss: 0.9068 - val_accuracy: 0.6618
# Epoch 40/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0253 - accuracy: 0.9949 - val_loss: 0.8834 - val_accuracy: 0.6647
# Epoch 41/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0248 - accuracy: 0.9971 - val_loss: 0.8814 - val_accuracy: 0.6647
# Epoch 42/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0662 - accuracy: 0.9884 - val_loss: 0.8831 - val_accuracy: 0.6127
# Epoch 43/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0147 - accuracy: 0.9978 - val_loss: 0.8486 - val_accuracy: 0.6647
# Epoch 44/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0562 - accuracy: 0.9877 - val_loss: 0.8155 - val_accuracy: 0.6676
# Epoch 45/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0382 - accuracy: 0.9920 - val_loss: 0.7749 - val_accuracy: 0.7052
# Epoch 46/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0212 - accuracy: 0.9942 - val_loss: 0.7777 - val_accuracy: 0.7254
# Epoch 47/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0201 - accuracy: 0.9949 - val_loss: 0.7537 - val_accuracy: 0.7052
# Epoch 48/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0189 - accuracy: 0.9957 - val_loss: 0.6926 - val_accuracy: 0.9682
# Epoch 49/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0648 - accuracy: 0.9891 - val_loss: 0.6586 - val_accuracy: 1.0000
# Epoch 50/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0335 - accuracy: 0.9942 - val_loss: 0.7944 - val_accuracy: 0.4249
# Epoch 51/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0096 - accuracy: 0.9993 - val_loss: 0.8567 - val_accuracy: 0.3324
# Epoch 52/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.7860 - val_accuracy: 0.3497
# Epoch 53/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0125 - accuracy: 0.9978 - val_loss: 0.7495 - val_accuracy: 0.4046
# Epoch 54/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.6635 - val_accuracy: 0.6908
# Epoch 55/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0361 - accuracy: 0.9920 - val_loss: 0.5823 - val_accuracy: 0.8699
# Epoch 56/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.5464 - val_accuracy: 0.9162
# Epoch 57/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0404 - accuracy: 0.9899 - val_loss: 0.5239 - val_accuracy: 0.8208
# Epoch 58/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0262 - accuracy: 0.9920 - val_loss: 0.6296 - val_accuracy: 0.7052
# Epoch 59/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.5436 - val_accuracy: 0.7861
# Epoch 60/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0112 - accuracy: 0.9978 - val_loss: 0.5720 - val_accuracy: 0.7399
# Epoch 61/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0096 - accuracy: 0.9986 - val_loss: 0.4710 - val_accuracy: 0.7890
# Epoch 62/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0160 - accuracy: 0.9971 - val_loss: 0.4249 - val_accuracy: 0.7890
# Epoch 63/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0226 - accuracy: 0.9942 - val_loss: 0.3476 - val_accuracy: 0.9884
# Epoch 64/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.3187 - val_accuracy: 0.9277
# Epoch 65/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 0.2584 - val_accuracy: 1.0000
# Epoch 66/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0120 - accuracy: 0.9971 - val_loss: 0.2270 - val_accuracy: 1.0000
# Epoch 67/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0104 - accuracy: 0.9978 - val_loss: 0.1828 - val_accuracy: 1.0000
# Epoch 68/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.1900 - val_accuracy: 0.9971
# Epoch 69/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0372 - accuracy: 0.9920 - val_loss: 0.1385 - val_accuracy: 1.0000
# Epoch 70/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0197 - accuracy: 0.9949 - val_loss: 0.1405 - val_accuracy: 0.9913
# Epoch 71/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.1239 - val_accuracy: 1.0000
# Epoch 72/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0370 - accuracy: 0.9913 - val_loss: 0.2541 - val_accuracy: 0.9017
# Epoch 73/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0083 - accuracy: 0.9993 - val_loss: 0.2720 - val_accuracy: 0.9884
# Epoch 74/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0155 - accuracy: 0.9978 - val_loss: 0.1989 - val_accuracy: 1.0000
# Epoch 75/150
# 87/87 [==============================] - 2s 26ms/step - loss: 0.0376 - accuracy: 0.9935 - val_loss: 0.1720 - val_accuracy: 0.9913
# Epoch 76/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.1148 - val_accuracy: 1.0000
# Epoch 77/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0278 - accuracy: 0.9899 - val_loss: 0.1137 - val_accuracy: 1.0000
# Epoch 78/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0409 - accuracy: 0.9906 - val_loss: 0.1136 - val_accuracy: 1.0000
# Epoch 79/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0131 - accuracy: 0.9964 - val_loss: 0.1387 - val_accuracy: 0.9942
# Epoch 80/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.1006 - val_accuracy: 1.0000
# Epoch 81/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0095 - accuracy: 0.9978 - val_loss: 0.0706 - val_accuracy: 1.0000
# Epoch 82/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0169 - accuracy: 0.9949 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 83/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0230 - accuracy: 0.9957 - val_loss: 0.0494 - val_accuracy: 1.0000
# Epoch 84/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.0749 - val_accuracy: 1.0000
# Epoch 85/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0612 - val_accuracy: 1.0000
# Epoch 86/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0105 - accuracy: 0.9957 - val_loss: 0.0693 - val_accuracy: 1.0000
# Epoch 87/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0213 - accuracy: 0.9949 - val_loss: 0.0652 - val_accuracy: 1.0000
# Epoch 88/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0107 - accuracy: 0.9986 - val_loss: 0.0619 - val_accuracy: 1.0000
# Epoch 89/150
# 87/87 [==============================] - 2s 26ms/step - loss: 0.0070 - accuracy: 0.9993 - val_loss: 0.0488 - val_accuracy: 1.0000
# Epoch 90/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0182 - accuracy: 0.9935 - val_loss: 0.0433 - val_accuracy: 1.0000
# Epoch 91/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0170 - accuracy: 0.9964 - val_loss: 0.1247 - val_accuracy: 1.0000
# Epoch 92/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0107 - accuracy: 0.9978 - val_loss: 0.0591 - val_accuracy: 1.0000
# Epoch 93/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0397 - val_accuracy: 1.0000
# Epoch 94/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0055 - accuracy: 0.9993 - val_loss: 0.0498 - val_accuracy: 1.0000
# Epoch 95/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0319 - val_accuracy: 1.0000
# Epoch 96/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 1.0000
# Epoch 97/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 98/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 99/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0132 - accuracy: 0.9978 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 100/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0123 - accuracy: 0.9978 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 101/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 0.0297 - val_accuracy: 1.0000
# Epoch 102/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0051 - accuracy: 0.9993 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 103/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 104/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 105/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 106/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 107/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0159 - accuracy: 0.9978 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 108/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 109/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 110/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 111/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 112/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0252 - accuracy: 0.9949 - val_loss: 0.0265 - val_accuracy: 1.0000
# Epoch 113/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0068 - accuracy: 0.9971 - val_loss: 0.0345 - val_accuracy: 1.0000
# Epoch 114/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0194 - accuracy: 0.9964 - val_loss: 0.0423 - val_accuracy: 0.9913
# Epoch 115/150
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.0401 - val_accuracy: 0.9913
# Epoch 116/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 117/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 1.0000
# Epoch 118/150
# 87/87 [==============================] - 2s 21ms/step - loss: 0.0052 - accuracy: 0.9993 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 119/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0152 - accuracy: 0.9935 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 120/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 121/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 122/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 123/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0319 - val_accuracy: 1.0000
# Epoch 124/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0172 - accuracy: 0.9964 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 125/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 126/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 127/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0161 - accuracy: 0.9964 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 128/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0204 - accuracy: 0.9928 - val_loss: 0.1826 - val_accuracy: 0.9162
# Epoch 129/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0189 - accuracy: 0.9957 - val_loss: 0.0488 - val_accuracy: 0.9942
# Epoch 130/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 131/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0134 - accuracy: 0.9957 - val_loss: 0.0424 - val_accuracy: 1.0000
# Epoch 132/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0224 - accuracy: 0.9964 - val_loss: 0.0270 - val_accuracy: 1.0000
# Epoch 133/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0180 - accuracy: 0.9978 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 134/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 135/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 136/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 137/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 138/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 139/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 140/150
# 87/87 [==============================] - 2s 23ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 141/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 142/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0061 - accuracy: 0.9971 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 143/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 144/150
# 87/87 [==============================] - 2s 24ms/step - loss: 7.4841e-04 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 145/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0235 - accuracy: 0.9971 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 146/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 147/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 148/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0144 - accuracy: 0.9942 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 149/150
# 87/87 [==============================] - 2s 25ms/step - loss: 0.0182 - accuracy: 0.9935 - val_loss: 0.0265 - val_accuracy: 1.0000
# Epoch 150/150
# 87/87 [==============================] - 2s 24ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.0144 - val_accuracy: 1.0000
# Training time: 317.481 sec
# Score for train dataset
# 44/44 [==============================] - 1s 9ms/step - loss: 0.0130 - accuracy: 1.0000
# Score:
# loss : 0.01295759342610836
# loss : 100.0 %

# %%
def plotHistory(history, train, validation):
    """
        plot training history
        Parameters
        ------------------------------
        history = history
        train = 'accuracy' or 'loss'
        validation = 'val_accuracy' or 'val_loss'
    """
    plt.figure(figsize= (8, 6))
    plt.plot(history.history[train])
    plt.plot(history.history[validation])
    plt.legend(['train', 'validation'], loc= 'center right')
    plt.xlabel("Epochs")
    if train == 'accuracy':
        plt.ylabel("Accuracy")
        plt.title(f"Accuracy for train dataset")
    elif train == "loss":
        plt.ylabel("Loss")
        plt.title("Loss for train dataset")
    plt.show()

# %%
plotHistory(history= history, train= 'accuracy', validation= 'val_accuracy')
plotHistory(history= history, train= 'loss', validation= 'val_loss')

# %%
# Evaluate test dataset
testScore = model.evaluate(X_test, testTargets, verbose= 1)
print(f"{model.metrics_names[0]} : {testScore[0]}\n{model.metrics_names[1]} : {testScore[1] * 100} %")
# Out:
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0122 - accuracy: 1.0000
# loss : 0.012171430513262749
# accuracy : 100.0 %

# %%
# Prediction for test dataset

prediction = model.predict(X_test)
predictionClass = np.argmax(prediction, axis= 1)        # One-hot encoding --> Original label

# Actual Class (One-hot encoding testTarget --> y_test)
if testTargets.ndim > 1:
    actualClass = np.argmax(testTargets, axis= 1)
else:
    actualClass = testTargets

# Classification report
print(f"Classification report: \n{classification_report(actualClass, predictionClass)}")

# Confusion matrix
plt.figure(figsize= (8, 6))
sns.heatmap(confusion_matrix(actualClass, predictionClass), 
            annot= True, 
            fmt= "d", 
            cmap= "Blues",
            cbar= False)
plt.title("Confusion matrix for test dataset")
plt.xlabel("Prediction class")
plt.ylabel("Actual class")
plt.show()
# Out:
# 14/14 [==============================] - 1s 8ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       144
#            1       1.00      1.00      1.00       144
#            2       1.00      1.00      1.00       144
#
#     accuracy                           1.00       432
#    macro avg       1.00      1.00      1.00       432
# weighted avg       1.00      1.00      1.00       432

# %%
# Prediction for 1 image

randomImgIdx = random.randrange(0, X_test.shape[0])

predictStartTime = time.time()

predictionImg = X_test[randomImgIdx]
predictionImg = np.expand_dims(predictionImg, axis= 0)

testPrediction = model.predict(predictionImg)

predictEndTime = time.time()

print("Random image index: ", randomImgIdx)
print("Random actual label: ", i_test[randomImgIdx])
print("Random actual class: ", actualClass[randomImgIdx])
print("Random prediction class: ", predictionClass[randomImgIdx])
# Out:
# 1/1 [==============================] - 0s 249ms/step
# Random image index:  26
# Random actual label:  L_54
# Random actual class:  1
# Random prediction class:  1
